# %% [markdown]
# ## Seasonal NAO skill comparison ##
#
# In the decadal predictions, we observe a pretty significant drop in skill post-2005 initiailisation. As the dataset is limited to around 50 years and we have only observed one 'forecast bust' like this, we don't know whether Doug was just lucky or whether something is actually going wrong in the models in the recent period.
#
# To explore this, we consider the seasonal hindcasts:
#
# 1. CSF-20C (Coupled Seasonal Forecast):This is a hindcast performed with the model fully coupled to the Nucleus for European Modelling of the Ocean (NEMO) ocean model, initialised from CERA-20C reanalysis data.
# 2. ASF-20C (Atmospheric Seasonal Forecasts): This is a hindcast performed with prescribed Sea Surface Temperature (SST) and sea-ice boundary conditions at the surface, initialised form ERA-20C reanalysis data.
#
# These both run from initialisation in 1901-2009, so give a longer time period.
#
# Strommen et al. (2023) propose that seasonal forecasts can be used to diagnose decadal forecast signals over a longer period. We plan to look at this in the context of 8 year running mean (years 2-9 of the decadal forecast) NAO predictability. In doing this, we want to explore the following questions:
#
# * Was the recent drop in NAO skill an outlier in the longer period (1901-2020)?
# * Have similar 'forecast bust' periods been observed before?
# * Are there similar conditions occuring during previous bust periods?
#     * i.e. divergence of model/obs SPNA SSTs

# %%
# Import relevant modules
import os
import sys

# Third party imports
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# Testing dask again
import dask
import dask.array as da

# Import cdo for regridding
from cdo import Cdo
cdo = Cdo()

# %%
# Import local dictionaries and functions
sys.path.append('/home/users/benhutch/skill-maps')

# Import dictionaries
import dictionaries as dic

# Set up the path where the functions are stored
sys.path.append('/home/users/benhutch/skill-maps/python')

# Import functions
import functions as func

# Import the NAO skill functions
import nao_skill_functions as nao_func

# Set up the path where the functions are stored
sys.path.append('/home/users/benhutch/skill-maps/rose-suite-matching')

# Import the suite functions
import nao_matching_seasons as nms_func

# Import the bootstrapping functions
import process_bs_values as pbs_func

# %% [markdown]
# ### Data access issues ###
#
# * ERA20C reanalysis not easily accessible?
# * Who should I contact to try to get access?
# * Maybe just look back to 1940 onwards (ERA5 window) first

# %%
# Find some of the ASF20C data on jasmin
# Set up the parameters
model = "ASF20C" # Alternative is "CSF20C"
variable = "SLP" # Sea level pressure
initialisation = "Nov" # Month of initialisation
year = 1901 # First year of the hindcast
member=1 # Ensemble member
region="Global" # For regridding

# Set up the base path
base_path_20c = "/badc/deposited2020/seasonal-forecasts-20thc/data"

# Find the specific file
folder_name = f"{variable}monthly_{model}_{initialisation}START_ENSmems"

# Set up the file name
file_name = f"{variable}monthly_{year}_M{member}.nc"

# Set up the full path
file_path = os.path.join(base_path_20c, model,
                            folder_name, file_name)

# Check if the file exists
if os.path.exists(file_path):
    print(f"The file {file_path} exists")

# Set up directories in canari to store the regridded psl data
# Set up the base path
base_path = "/gws/nopw/j04/canari/users/benhutch"

# Form a new path
new_path_ASF20C = os.path.join(base_path, "seasonal",
                               "ASF20C", variable,
                                 f"{initialisation}_START")

# Same for the CSF20C
new_path_CSF20C = os.path.join(base_path, "seasonal",
                               "CSF20C", variable,
                                 f"{initialisation}_START")

# Check if the directories exist
if not os.path.exists(new_path_ASF20C):
    print(f"The directory {new_path_ASF20C} exists")
    # Create a new directory
    os.makedirs(new_path_ASF20C, exist_ok=False)

# Same for the CSF20C
if not os.path.exists(new_path_CSF20C):
    print(f"The directory {new_path_CSF20C} exists")
    # Create a new directory
    os.makedirs(new_path_CSF20C, exist_ok=False)
# Out:
# The file /badc/deposited2020/seasonal-forecasts-20thc/data/ASF20C/SLPmonthly_ASF20C_NovSTART_ENSmems/SLPmonthly_1901_M1.nc exists

# %%
# Find the gridspec for the file
gridspec_dir = "/home/users/benhutch/gridspec/"

# # Print all of the files within the directory
# print(os.listdir(gridspec_dir))

# Find gridspec-global.txt
gridspec_file = os.path.join(gridspec_dir, "gridspec-global.txt")

# Print the contents of the file
print(open(gridspec_file).read())
# Out:
# gridtype=lonlat
# xfirst=-180
# xinc=2.5
# xsize=144
# yfirst=-90
# yinc=2.5
# ysize=72

# %%
# Find the directory where all of the data to be regridded is stored
dir = os.path.join(base_path_20c, model,
                            folder_name)

# # Print all of the files within the directory
# print(os.listdir(dir))

# # Find the files within the directory
# files = os.listdir(dir)

# # Limit files to the first 10
# files = files[:10]

# # Loop through the files
# for file in files:
#     # Set up the output file name
#     output_file = os.path.join(new_path_ASF20C, f"{file[:-3]}_rg.nc")

#     # If the output file already exists, skip
#     if os.path.exists(output_file):
#         print(f"The file {output_file} exists")
#         continue

#     # Set up the input file name
#     input_file = os.path.join(dir, file)

#     # perform the regridding
#     cdo.remapbil(gridspec_file, input=input_file,
#                  output=output_file)

# %% [markdown]
# ### Time ###
#
# The timesteps for the seasonal forecasts are set up in a weird way. We are going to assume that if the forecast is initialized on the 1st November and then run forwards for four months, then the first timestep is the November mean, the second December, then January and February. Therefore, to get the DJF mean, we will take the average of all time steps but the first.

# %%
#Import pandas
import pandas as pd

# # Find my directory with the regridded data
# # Print the files contained within new_path_ASF20C
# print(os.listdir(new_path_ASF20C))

# Create an array of initialisation years
years = np.arange(1901, 2011)

# For a single file, collapse this into a DJF mean
# First calculate the anomaly field
# Then calculate the DJF mean anomalies
# Then azores gridbox mean - iceland gridbox mean
# Do this for a single file first as a test
test_file = os.path.join(new_path_ASF20C, "SLPmonthly_1901_M1_rg.nc")

# Read in the file
ds = xr.open_dataset(test_file)

ds

# # Extract the lats and lons
lats = ds['lat']
lons = ds['lon']

# Generate an array of years from 1901 to 2009
years = np.arange(1901, 2010)

# Generate an array for the members from 1 to 50
members = np.arange(1, 51)

# Print the shape of the data
print(np.shape(lats))
print(np.shape(lons))
print(np.shape(years))
print(np.shape(members))

# Extract the data for the variable: 'MSL_GDS0_SFC'
data = ds['MSL_GDS0_SFC']

# Print the shape of the data
print(data.shape)

# Take the mean over the time dimension
djf_mean = data[1:, :, :].mean(axis=0)

# Print the shape of the data
print(djf_mean.shape)

# Print the data
print(djf_mean)
# Out:
# (72,)
# (144,)
# (109,)
# (50,)
# (4, 72, 144)
# (72, 144)
# <xarray.DataArray 'MSL_GDS0_SFC' (lat: 72, lon: 144)>
# array([[100824.6 , 100824.6 , 100824.6 , ..., 100824.6 , 100824.6 ,
#         100824.6 ],
#        [100243.15, 100247.77, 100253.4 , ..., 100259.94, 100253.44,
#         100247.77],
#        [ 99846.35,  99874.48,  99851.52, ..., 100026.48,  99937.15,
#          99880.23],
#        ...,
#        [102820.85, 102822.23, 102824.94, ..., 102804.94, 102813.23,
#         102817.81],
#        [102873.69, 102879.85, 102886.85, ..., 102854.85, 102861.85,
#         102869.35],
#        [102807.19, 102810.77, 102814.1 , ..., 102792.31, 102797.56,
#         102802.48]], dtype=float32)
# Coordinates:
#   * lon      (lon) float64 -180.0 -177.5 -175.0 -172.5 ... 172.5 175.0 177.5
#   * lat      (lat) float64 -90.0 -87.5 -85.0 -82.5 -80.0 ... 80.0 82.5 85.0 87.5

# %%
# Start the dask client
from dask.distributed import Client, progress
client = Client(threads_per_worker=4, n_workers=1)
client
# Out:
# /apps/jasmin/jaspy/miniconda_envs/jaspy3.10/m3-4.9.2/envs/jaspy3.10-m3-4.9.2-r20220721/lib/python3.10/site-packages/distributed/node.py:179: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 44001 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:36360' processes=1 threads=4, memory=0.98 TiB>

# %%
# Add additional workers
client.cluster.scale(10)

# %%
# Generate an array of years from 1901 to 2009
years = np.arange(1901, 2010)

# Create an empty Dask array to store the data
asf_psl_field = da.empty([len(years), len(members)])

# Print the shape of the array
print(asf_psl_field.shape)

# Extract the lats and lons for the NAO region
iceland_lat1, iceland_lat2 = (
    dic.iceland_grid_corrected["lat1"],
    dic.iceland_grid_corrected["lat2"],
)
iceland_lon1, iceland_lon2 = (
    dic.iceland_grid_corrected["lon1"],
    dic.iceland_grid_corrected["lon2"],
)

azores_lat1, azores_lat2 = (
    dic.azores_grid_corrected["lat1"],
    dic.azores_grid_corrected["lat2"],
)
azores_lon1, azores_lon2 = (
    dic.azores_grid_corrected["lon1"],
    dic.azores_grid_corrected["lon2"],
)


# Define a function to process a single year and member
def process_year_member(year, member):
    # Print the year and member
    print("Processing year: ", year, " member: ", member)

    # Set up the file name
    file_name = f"SLPmonthly_{year}_M{member}_rg.nc"

    # Set up the file path
    file_path = os.path.join(new_path_ASF20C, file_name)

    # Read in the file
    ds = xr.open_dataset(file_path, chunks={"time": 100, "lat": 100, "lon": 100})

    # Read in the climatology file
    clim_file = os.path.join(new_path_ASF20C, "climatology", "full-climatology.nc")

    # Read in the file
    clim = xr.open_dataset(clim_file, chunks={"time": 100, "lat": 100, "lon": 100})

    # Extract the data for the variable: 'MSL_GDS0_SFC'
    data = ds["MSL_GDS0_SFC"]
    climatology = clim["MSL_GDS0_SFC"]

    # Remove the first time step
    data = data[1:, :, :]

    # Take the mean over the time dimension
    climatology = climatology.mean(axis=0)

    # Take the mean over the time dimension
    data = data.mean(axis=0)

    # Calculate the anomaly field
    data_anom = data - climatology

    # Take the mean over the spatial dimension of the iceland gridbox
    iceland_mean = data_anom.sel(
        lat=slice(iceland_lat1, iceland_lat2), lon=slice(iceland_lon1, iceland_lon2)
    ).mean(axis=(0, 1))

    # Take the mean over the spatial dimension of the azores gridbox
    azores_mean = data_anom.sel(
        lat=slice(azores_lat1, azores_lat2), lon=slice(azores_lon1, azores_lon2)
    ).mean(axis=(0, 1))

    # Calculate the NAO index
    nao_index = azores_mean - iceland_mean

    # Print the shape of the data
    print("shape of djf_mean: ", nao_index.shape)
    print("value of djf_mean: ", nao_index.values)

    # Return the Dask array
    return nao_index


# Create an empty list to store the results
results = []

# Loop through the years and members
# for year in years:
#     print("Processing year: ", year)

# # Set the year
# year = years[0]

# years_test = years[:5]

for year in years:
    print("Processing year: ", year)
    # Test the function
    for member in members:
        print("Processing member: ", member)

        # Use dask.delayed to delay the function and append the result to the list
        result = dask.delayed(process_year_member)(year, member)
        results.append(result)

# Print the results
print(results)
# Out:
# (109, 50)
# Processing year:  1901
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1902
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1903
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1904
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1905
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1906
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1907
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1908
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1909
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1910
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1911
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1912
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1913
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1914
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1915
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1916
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1917
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1918
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1919
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1920
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1921
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1922
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1923
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1924
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1925
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1926
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1927
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1928
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1929
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1930
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1931
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1932
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1933
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1934
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1935
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1936
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1937
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1938
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1939
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1940
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1941
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  1942
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# ...
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  2000
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  2001
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  2002
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  2003
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  2004
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  2005
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  2006
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  2007
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  2008
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# Processing year:  2009
# Processing member:  1
# Processing member:  2
# Processing member:  3
# Processing member:  4
# Processing member:  5
# Processing member:  6
# Processing member:  7
# Processing member:  8
# Processing member:  9
# Processing member:  10
# Processing member:  11
# Processing member:  12
# Processing member:  13
# Processing member:  14
# Processing member:  15
# Processing member:  16
# Processing member:  17
# Processing member:  18
# Processing member:  19
# Processing member:  20
# Processing member:  21
# Processing member:  22
# Processing member:  23
# Processing member:  24
# Processing member:  25
# Processing member:  26
# Processing member:  27
# Processing member:  28
# Processing member:  29
# Processing member:  30
# Processing member:  31
# Processing member:  32
# Processing member:  33
# Processing member:  34
# Processing member:  35
# Processing member:  36
# Processing member:  37
# Processing member:  38
# Processing member:  39
# Processing member:  40
# Processing member:  41
# Processing member:  42
# Processing member:  43
# Processing member:  44
# Processing member:  45
# Processing member:  46
# Processing member:  47
# Processing member:  48
# Processing member:  49
# Processing member:  50
# [Delayed('process_year_member-f94a6ea5-ce32-49c3-965d-925d6d62bc52'), Delayed('process_year_member-acc007b4-76f0-41f7-855b-1e1e41a2dd03'), Delayed('process_year_member-7ac4d908-a72a-495a-9f0c-6e0c39bd8c7b'), Delayed('process_year_member-5b2c7e05-429f-4b05-aefa-c3e770722e31'), Delayed('process_year_member-de5020fc-c745-407f-89bf-278d8ee7ca1f'), Delayed('process_year_member-3b710ffb-e49a-44d5-b6ac-91080b53f154'), Delayed('process_year_member-ed2dff0f-9a93-4641-b0d2-567829dc8cf1'), Delayed('process_year_member-9ced1c36-8c05-4ccf-afdd-3b4a78fea9c4'), Delayed('process_year_member-767731e2-3ecb-4cdc-848c-f751c2c679db'), Delayed('process_year_member-3df67a9f-b2a1-41d5-9f07-001852695637'), Delayed('process_year_member-758227f9-41cc-4438-bdc4-c267ef54392c'), Delayed('process_year_member-e961e30a-d69e-4c4c-8be1-bc5a545b8a51'), Delayed('process_year_member-295c0e0c-2e3b-4e39-919a-06bcd785fbaa'), Delayed('process_year_member-e83299a1-9dea-4939-8557-5cc2c6ea3060'), Delayed('process_year_member-12eafaba-5cf1-47c2-88a0-0f2b6901c755'), Delayed('process_year_member-5c7accf1-cb14-4b75-bd54-1792c758a5f8'), Delayed('process_year_member-932d4d8e-56ee-42ef-895e-34b4139e6498'), Delayed('process_year_member-7b925086-6077-4ff8-84fa-6c55ac7c0fde'), Delayed('process_year_member-de455351-9311-4236-b305-e42a186cd9d8'), Delayed('process_year_member-ed6377cf-1198-48f8-bfad-d322fae82f3e'), Delayed('process_year_member-0ccffb90-4634-4756-a370-fc13271e45ab'), Delayed('process_year_member-92ef80d0-59c3-4cd3-8969-2e2f42c1505c'), Delayed('process_year_member-c4860807-278a-4295-a007-ff15f0a85d3f'), Delayed('process_year_member-503d73ba-eb59-4eed-8c0e-471f8ec5f9a6'), Delayed('process_year_member-6820d18c-8332-4a8b-beda-ac2e5beebaac'), Delayed('process_year_member-9025a31e-a1fd-4c7d-a298-87f30c458621'), Delayed('process_year_member-eef77f0a-48bc-42f7-bf82-c0babe572545'), Delayed('process_year_member-5fe8a017-ca36-4275-9808-b2031defe632'), Delayed('process_year_member-e5ca51d6-b5e4-4ebd-ad46-df68e0e2b8c4'), Delayed('process_year_member-34839b5b-10d2-4dcd-a7f8-7779ae9a0808'), Delayed('process_year_member-005f7c34-883d-4695-8113-94c354112323'), Delayed('process_year_member-1b6e6c3c-368c-433f-99f2-fd3a9ff85581'), Delayed('process_year_member-f199af45-1631-45cd-a779-fc143c6af1c6'), Delayed('process_year_member-c25f236f-ce61-469f-967c-6fcd1fc418d0'), Delayed('process_year_member-12fb8105-dc70-41b0-b046-146590c1850f'), Delayed('process_year_member-8bf5417e-1697-4119-b709-ed43dd5fc90f'), Delayed('process_year_member-85b751ef-ad69-486b-9e92-61d8460c559d'), Delayed('process_year_member-c8c60f53-bd04-42aa-a739-10f24032600b'), Delayed('process_year_member-8b7132a1-5ef9-4db8-970d-d045fc3578bb'), Delayed('process_year_member-e5a6eeb0-2d7b-4a34-a8da-b6d865257e27'), Delayed('process_year_member-88e97623-a8dd-4b11-b133-4cb9f6750da5'), Delayed('process_year_member-b72e9611-e7e8-4818-a6b9-588d2a5c0675'), Delayed('process_year_member-6b12493e-fa7a-4d4b-88aa-a8e8a8a3993a'), Delayed('process_year_member-d2be7223-ba72-443a-90a7-fbc38c0b83c5'), Delayed('process_year_member-7d483758-cc75-403d-b014-7e43475cc180'), Delayed('process_year_member-36685168-24aa-4af1-af9a-897e3c67b05a'), Delayed('process_year_member-663312df-ae35-47b4-8f9b-bcb9b89601cb'), Delayed('process_year_member-1d153ec3-1da5-4af7-a38a-d6f413081a94'), Delayed('process_year_member-c8f42838-e9ee-4cf3-99a9-57ad62eaa196'), Delayed('process_year_member-3610f042-7d6d-40b3-bc8e-4a0ba106d101'), Delayed('process_year_member-8f0658b1-77b8-42d9-a251-1aeb7ff42f3e'), Delayed('process_year_member-ec4bd67f-a81d-489c-a8a0-8eecbeb015a5'), Delayed('process_year_member-8f459a52-0b86-4ac8-8fa2-3a91f9fd3203'), Delayed('process_year_member-6ecad5e2-176b-4ed6-aa71-c1c5e3d38108'), Delayed('process_year_member-c9e62f8f-21be-4bfe-b2e6-91d45d9558f0'), Delayed('process_year_member-f8838a96-2876-40c1-9db6-854bdbcb76ee'), Delayed('process_year_member-ef699b8c-a4b0-4afa-8b49-166c99b4c9a2'), Delayed('process_year_member-50a46725-772a-4875-a36b-e2c1ce87bac7' ...

# %%
# Start the Dask computation
asf_psl_field_results = dask.compute(*results)

# Print the results
print(type(asf_psl_field_results))

# # Print the shape of the results
# print(asf_psl_field_results.shape)

# Print the results
print(asf_psl_field_results)

# Create a test dask array
test_dask_array = da.empty([len(years), len(members)])

# Print the shape of the array
print(test_dask_array.shape)

member_counter = 0
year_counter = 0

# Loop through the results
for i, result in enumerate(asf_psl_field_results):
    # Print the shape of the result
    print(f"result {i} has value: ", result)

    # Set the value of the dask array
    test_dask_array[year_counter, member_counter] = result

    # Increment the counters
    member_counter += 1

    # If the member counter is equal to the number of members
    if member_counter == len(members):
        # Reset the member counter
        member_counter = 0

        # Increment the year counter
        year_counter += 1

# Print the dask array shape
print(test_dask_array.shape)
# Out:
# Processing year: Processing year:  1987  member:   1960  member:  20
# 11
# Processing year:  1932  member: Processing year:  1915   member: 20
#  23
# Processing year: Processing year:  1906  member:  31
# Processing year:  1918 1903  member: Processing year:  5  member:  41
#
#  1952  member:  5
# Processing year: Processing year:  1971  member:   50
# Processing year: 1963Processing year:   member:   1991 1905  member: 8 20
#   member:
#  35
# Processing year: Processing year:  1947  1954Processing year:  member:  41
# 1922 Processing year:  1904  member: Processing year:  2003  member:   member:  member:   42
# Processing year: Processing year: 19
# 23 44
#  1937
#   member:  71974  member:
#  32
# Processing year:  1935  member: Processing year:   4
# Processing year:  19332006  member:  48
# Processing year:  1971  member:  9
# Processing year:  1970 Processing year:  member:  44
# Processing year:   1933  member:  Processing year: 196348
#  Processing year:  member:    1943  member: 1945   member: 4318 12
#
#
# Processing year: Processing year:  1963  member:   9
# 2006  member:  21Processing year:  1999  member:
# 30
# Processing year:  1927  member:  3
# Processing year:  Processing year:  1935  member:  1999  member: 41Processing year:    member:  23
# 1948 Processing year:   member:
# 35
# 2009 8  member:  19
#
# Processing year: Processing year:  1946  member:  1968  member:   39
# 18
# Processing year: Processing year:  1918  member:   2
# 1981  member:  3
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()shape of djf_mean: shape of djf_mean:  ()
#
# shape of djf_mean:  ()
#  ()
# shape of djf_mean:  ()
# shape of djf_mean: shape of djf_mean:   ()
# ()
# Processing year: Processing year:  1924  member:   1924  member:  36
# 9
# Processing year:  1949  member:  10
# Processing year:  1940  member:  14
# Processing year:  1956  member:  44
# Processing year:  1957  member:  20
# Processing year:  1980  member: Processing year:  1
#  1941  member:  25
# Processing year:  2007  member:  34
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year: Processing year:  1997  member:  13
#  1906  member:  43
# Processing year:  1986  member:  31
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1973  member:  27
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean: Processing year:  1952  member:  44
#  ()
# shape of djf_mean:  ()
# Processing year:  1927  member:  40
# Processing year:  1917  member:  14
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1905  member:  38
# shape of djf_mean:  ()shape of djf_mean:
#  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()shape of djf_mean:
#  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean: shape of djf_mean:  ()
#  ()
# shape of djf_mean:  ()
# Processing year: Processing year: Processing year:  1963  member:  1950  member:   50
# 1950  member:   Processing year:  1941  member: 3
#  1715
#
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year: Processing year:  1978  member:  27
#  1978  member:  32
# Processing year:  1907  member:  2
# Processing year: Processing year:  1925 2009   member:   member:  1516
#
# Processing year:  1987  member:  Processing year:  Processing year:  19511941  member: 32Processing year:  1970   member:  47
#
#   member:  240
#
# shape of djf_mean:  ()
# Processing year:  1940  member:  43
# shape of djf_mean:  ()
# Processing year:  2005  member:  45
# Processing year:  1941  member:  5
# Processing year:  Processing year:  1919 Processing year:  member:  36
# 1954  member:  28
#  2002  member:  3
# shape of djf_mean:  ()
# shape of djf_mean: shape of djf_mean:  ()
# shape of djf_mean:  () ()
#
# Processing year:  1971 Processing year:  member:  46
#  1928  member:  2
# Processing year:  1914  member:  38
# Processing year:  1937  member:  4
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1966  member: Processing year:  1993  member:  Processing year:  1916  member: Processing year:  1963   9
# 41
# 32
#  member:  2
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1911  member:  44
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1980  member:  46
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1940  member:  9
# shape of djf_mean:  ()
# Processing year:  1941  member:  13
# shape of djf_mean:  ()
# Processing year:  1994  member:  48
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1973  member:  20
# shape of djf_mean:  ()
# Processing year:  1997  member:  20
# Processing year:  1952  member:  39
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1987  member:  1
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1923  member:  23
# Processing year:  1973  member:  43
# Processing year:  1982  member:  32
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year: Processing year:  1956  member:  49
#  1970  member:  30
# Processing year:  1939  member:  25
# shape of djf_mean:  ()
# Processing year:  1924  member:  32
# shape of djf_mean:  ()
# Processing year:  1916  member:  2
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1951  member:  50
# shape of djf_mean:  ()
# shape of djf_mean: shape of djf_mean:  ()
#  ()
# Processing year:  1919  member:  39
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year: Processing year:  1902  1925 Processing year:  1918  member:   member:  35
# Processing year:  13
# 1934  member:  member:  32 20
#
# Processing year:  1920  member:  28
# shape of djf_mean:  ()
# Processing year:  1970  member:  43
# shape of djf_mean:  ()
# Processing year:  1995  member:  28
# Processing year:  1949  member:  48
# shape of djf_mean:  ()
# Processing year:  1950  member:  11
# shape of djf_mean:  ()
# Processing year:  1937  member:  1
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean: shape of djf_mean:   ()
# ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean: Processing year:  1919  member:  47
# Processing year:  2004  member:  shape of djf_mean: 40Processing year:   ()1922
#
#  member:  27
#  ()
# Processing year:  shape of djf_mean:  ()
# 1932  member:  22
# shape of djf_mean:  ()
# Processing year:  1975  member:  27
# Processing year:  1921  member:  11
# Processing year:  1950  member: Processing year:  1978  9
#  member:  26
# Processing year:  1921  member:  20
# shape of djf_mean: shape of djf_mean:  ()
# shape of djf_mean:  ()
#  ()
# shape of djf_mean:  ()
# Processing year:  1905  member:  25
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1932  member:  29
# Processing year:  1903  member: shape of djf_mean:   11
# ()
# Processing year: Processing year:  1997   member: 1958  member:  4
#  33
# Processing year:  1921  member:  7
# Processing year:  1998  member:  30
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1925  member:  6
# Processing year:  1929  member:  3
# shape of djf_mean:  ()
# Processing year:  1985  member:  19
# Processing year:  1907  member:  31
# shape of djf_mean:  ()
# Processing year:  1907  member:  48
# shape of djf_mean:  ()
# Processing year:  1918  member:  50
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1919  member:  25
# shape of djf_mean: Processing year:  1901  member:  31
# shape of djf_mean:  ()
# Processing year:  1902  member:  37
# shape of djf_mean:  ()
# Processing year:  1941  member:  10
#  ()
# Processing year:  1903  member:  35
# shape of djf_mean:  ()
# Processing year:  1996  member:  40
# Processing year: Processing year:   1934 1945  member:   member: 5
# Processing year:  39
#  shape of djf_mean:  ()
# 1937  member:  16
# Processing year:  1907  member:  9
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1967  member:  36
# value of djf_mean:  -767.85
# value of djf_mean:  412.6735
# Processing year:  1902  member:  26
# shape of djf_mean:  ()shape of djf_mean:
#  ()
# value of djf_mean:  -148.80176
# Processing year:  1916  member:  35
# Processing year: Processing year:  1944  member:  1954  member:  24
#  9
# shape of djf_mean:  ()
# Processing year:  1923  member: Processing year:   491986
#  member:  36
# shape of djf_mean:  ()
# value of djf_mean:  -1033.8215
# Processing year:  1924  member:  46
# Processing year:  1994  member:  50
# shape of djf_mean:  ()
# value of djf_mean:  1130.4333
# value of djf_mean:  -943.58167
# value of djf_mean:  448.09018
# Processing year:  1971  member:  30
# shape of djf_mean:  ()
# Processing year:  1943  member:  11
# shape of djf_mean:  ()
# value of djf_mean:  281.52832
# Processing year:  1926  member:  16
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean: shape of djf_mean:  ()
#  ()
# shape of djf_mean:  ()
# Processing year:  1985  member:  31
# shape of djf_mean:  ()
# Processing year:  1978  member:  28
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1989  member:  36
# shape of djf_mean:  ()
# Processing year:  1976  member:  9
# Processing year:  1981  member:  29
# shape of djf_mean:  ()
# value of djf_mean:  shape of djf_mean: 89.342125
#  ()
# value of djf_mean:  1032.0725
# Processing year:  2005  member:  34
# Processing year:  1993  member:  38
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1967  member:  14
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1904  member:  49
# Processing year:  1931  member:  4
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year: Processing year:  2001   member: 1962  3
#  member:  38
# shape of djf_mean:  ()
# Processing year:  1984  member:  2
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year: Processing year: Processing year:  1977  1997  2005  member:  member:   47
#  member:  17
# 3
# Processing year:  1939  member:  20
# shape of djf_mean:  ()
# shape of djf_mean: shape of djf_mean:  () ()
#
# Processing year: Processing year:  1935  member:  1918  member:   1438
#
# shape of djf_mean:  ()
# Processing year:  1997  member:  40
# Processing year:  2002  member:  35
# Processing year:  1978  member:  37
# shape of djf_mean:  ()
# value of djf_mean:  200.07195
# Processing year:  1954  member:  1
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1990  member:  11
# Processing year: Processing year:  1975  member:  Processing year:  311970  member:   1992
# 47
#  member:  48
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1936  member:  4
# shape of djf_mean:  ()
# value of djf_mean:  560.07355
# value of djf_mean:  200.57161
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1926  member:  5
# Processing year:  1905  member:  48
# Processing year:  1993  member:  35
# shape of djf_mean:  ()
# Processing year:  1956  member:  15
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1911  member:  30
# Processing year:  1980  member:  17
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1923  member:  19
# Processing year:  2005  member:  47
# shape of djf_mean:  ()
# Processing year:  2008  member:  33
# Processing year:  1940  member:  6
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1979  member:  19
# shape of djf_mean:  ()
# shape of djf_mean: value of djf_mean:  ()
#  1167.3512
# value of djf_mean:  -2249.436
# value of djf_mean:  1159.9895
# Processing year:  1919  member: Processing year:  35
#  1985  member:  Processing year:  1916  member:  40
# 1
# Processing year:  2008  member:  17
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean: shape of djf_mean:  () ()
#
# shape of djf_mean:  ()
# value of djf_mean:  -505.57422
# value of djf_mean:  526.54944
# Processing year:  1950  member:  26
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1983  member:  43
# shape of djf_mean:  ()
# Processing year:  1981  member:  39
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1994 Processing year:  member:  35 1959  member:  45
#
# Processing year:  1959  member:  41
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# value of djf_mean:  -824.459
# value of djf_mean:  -183.52603
# value of djf_mean:  796.9792
# value of djf_mean:  506.29395
# Processing year:  1950  member:  40
# value of djf_mean:  2021.1113
# value of djf_mean:  -475.9437
# value of djf_mean:  200.04753
# value of djf_mean:  484.53842
# shape of djf_mean:  ()
# value of djf_mean:  -635.80725
# value of djf_mean:  -159.01237
# shape of djf_mean:  ()
# Processing year: Processing year:  1978  member:  23
#  1998  member:  27
# value of djf_mean:  665.85706
# Processing year:  1912  member:  3
# shape of djf_mean:  ()shape of djf_mean:  ()
# shape of djf_mean:
#  ()
# shape of djf_mean:  ()
# Processing year:  1980  member:  28
# Processing year:  Processing year:  1913  member: 1909  member:  33
#  36
# Processing year:  1926  member:  32
# shape of djf_mean:  ()
# shape of djf_mean:  shape of djf_mean:  ()
# ()
# Processing year: Processing year: Processing year:  1949  member:  1905  member:   37
# 1945  member:  39
#  40
# shape of djf_mean:  ()
# value of djf_mean:  -95.99251
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year: Processing year:  1956  member:  1978  member:  43
#  43
# Processing year:  1955  member:  16
# Processing year:  1932  member:  17
# Processing year:  1951  member:  40
# Processing year:  1952  member:  31
# Processing year:  2000  member:  23
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1958  member:  7
# value of djf_mean:  -13.554039
# Processing year: Processing year:  2009  member:  1935  member:  33
#  46
# shape of djf_mean:  ()
# Processing year:  1998  member:  22
# shape of djf_mean:  ()
# value of djf_mean:  -217.25162
# Processing year:  1981  member:  50
# value of djf_mean:  -220.94629
# Processing year:  1909  member:  25
# shape of djf_mean:  ()
# Processing year:  1955  member:  48
# shape of djf_mean:  ()
# Processing year:  1925  member:  9
# shape of djf_mean:  ()
# Processing year:  1913  member:  19
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# value of djf_mean:  -1326.7561
# Processing year:  1907  member:  42
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1917  member:  8
# shape of djf_mean:  ()
# Processing year:  1963  member:  11
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year: Processing year:  1937  member:  9
#  1943  member:  27
# Processing year:  1982  member:  49
# Processing year:  1934Processing year:  1902  member:  33
#   member:  39
# shape of djf_mean:  ()
# Processing year:  1979  member:  34
# shape of djf_mean: Processing year:  1984  member:  17
#  ()
# shape of djf_mean:  ()
# Processing year:  1939  member:  44
# shape of djf_mean:  ()
# Processing year:  1999  member:  50
# Processing year:  1927  member:  44
# Processing year:  1948  member:  31
# shape of djf_mean:  ()
# Processing year:  2007  member:  48
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# value of djf_mean:  67.32584
# value of djf_mean:  -718.69824
# value of djf_mean:  -557.04297
# shape of djf_mean:  ()
# Processing year:  1999  member:  26
# Processing year:  2000  member:  15
# shape of djf_mean:  ()
# Processing year:  1911  member:  40
# shape of djf_mean:  ()
# shape of djf_mean: value of djf_mean:  -503.028
#  ()
# value of djf_mean:  -438.35645
# value of djf_mean:  109.16829value of djf_mean:  -1501.0898
#
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  Processing year: Processing year:  1973  member:  19941915   member:  member:  12 27
#  32
#
# Processing year:  1934  member:  34
# Processing year:  2003  member:  13
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# value of djf_mean:  519.33136
# Processing year:  1939  member:  8
# Processing year: Processing year:  1959  1903  member:  18
#  member:  49
# shape of djf_mean:  ()
# Processing year:  1971  member:  37
# shape of djf_mean:  ()
# Processing year:  1988  member:  1
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1916  member:  20
# shape of djf_mean:  ()
# Processing year:  1913  member:  43
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1951  member:  Processing year: 37
#  1910  member:  30
# shape of djf_mean:  ()
# Processing year:  1995  member:  37
# shape of djf_mean:  ()
# Processing year:  1951  member:  47
# Processing year:  1920  member:  35
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# value of djf_mean:  1730.0789
# value of djf_mean: value of djf_mean: value of djf_mean:  653.2041
#  1274.3975
#  shape of djf_mean:  ()
# Processing year:  1970  member:  32
# Processing year:  1937  member:  19
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# value of djf_mean:  -316.62598
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1927  member:  34
# Processing year:  1907  member:  33
# shape of djf_mean:  ()
# Processing year:  1999  member:  48
# shape of djf_mean:  ()
# Processing year:  1916  member:  9
# -576.2282
# Processing year:  1918  member:  46Processing year:
#  1920  member:  5
# Processing year: Processing year:  1913   member: 1904   member:  3450
#
# Processing year:  1963  member:  35
# shape of djf_mean:  ()shape of djf_mean:
# ()
# value of djf_mean:  -388.55176
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  shape of djf_mean: ()
#  ()
# shape of djf_mean:  ()
# shape of djf_mean: shape of djf_mean:  ()shape of djf_mean:
#  ()
#  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1925  member:  Processing year: 7
# Processing year:  1984  member:  30 1947 Processing year:  1934  member:  31
#  member:  16
#
# Processing year:  Processing year:  1911  member: 1925 16
#   member:  34
# Processing year:  1925  member:  10
# Processing year:  2007  member:  10
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1910  member:  13
# value of djf_mean:  -820.9017
# Processing year:  2000  member:  49
# shape of djf_mean:  ()
# shape of djf_mean:  ()shape of djf_mean:
#  ()
# Processing year: Processing year:  1922  1910  member:  31
#  member:  14
# Processing year:  1999  member:  42
# shape of djf_mean:  ()
# value of djf_mean:  -58.816406
# shape of djf_mean:  ()
# value of djf_mean: value of djf_mean:  554.125
#  1010.00323
# value of djf_mean:  472.13214
# value of djf_mean:  757.7379
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1998  member:  49
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1924  member:  25
# shape of djf_mean:  ()
# Processing year:  1950  member:  25
# value of djf_mean:  -655.7409
# value of djf_mean:  738.0964
# value of djf_mean:  696.8281
# shape of djf_mean:  ()
# value of djf_mean:  58.45279
# shape of djf_mean: value of djf_mean:   ()
# -1022.9619
# value of djf_mean:  -107.23958
# value of djf_mean:  -263.2643
# value of djf_mean:  446.49805
# Processing year: Processing year:   1903  member:  2007  member:  49
# 47
# Processing year:  1915  member:  39
# shape of djf_mean:  ()shape of djf_mean:
#  ()
# Processing year:  1910  member:  2
# value of djf_mean:  549.55176
# Processing year:  1971  member:  12
# Processing year:  2005  member:  24
# Processing year:  1958  member:  12
# shape of djf_mean:  ()
# Processing year:  1994  member:  39
# value of djf_mean:  726.14716
# shape of djf_mean:  ()
# value of djf_mean:  -1626.3342
# Processing year:  1996  member:  36
# Processing year:  1991  member:  24
# Processing year:  1984  member:  28
# value of djf_mean:  149.75359
# Processing year:  1963  member:  26
# Processing year: Processing year:  1916  member:  37
#  1974  member:  47
# Processing year:  1940  member:  47
# value of djf_mean:  -504.0482
# Processing year:  1981  member:  41
# shape of djf_mean:  ()
# value of djf_mean:  408.85547
# value of djf_mean:  1628.1719
# value of djf_mean:  -150.65005
# value of djf_mean:  698.5212
# value of djf_mean:  812.62823
# value of djf_mean:  484.00064
# value of djf_mean:  462.88995
# value of djf_mean:  -110.5765
# Processing year:  1997  member:  38
# value of djf_mean:  38.181313
# value of djf_mean:  -698.014
# value of djf_mean:  -84.12174
# shape of djf_mean:  ()
# Processing year:  1928  member:  34
# shape of djf_mean:  ()
# Processing year:  1993  member:  30
# shape of djf_mean:  ()
# Processing year:  1966  member:  13
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# value of djf_mean:  1116.6605
# value of djf_mean:  934.95575
# value of djf_mean:  -233.55469
# shape of djf_mean:  ()
# value of djf_mean:  -1049.3203
# shape of djf_mean: value of djf_mean:   ()504.82257
#
# value of djf_mean:  -229.70377
# value of djf_mean:  -949.26074
# value of djf_mean:  -10.562826
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1984 Processing year:  1946  member: Processing year:  1902  member:  30 member:
#  22
# 35
# shape of djf_mean:  shape of djf_mean: ()
# shape of djf_mean:  ()
#  ()
# shape of djf_mean:  value of djf_mean: value of djf_mean:  37.047546
#  129.53418
# Processing year:  2005  member:  22
# Processing year: Processing year:  1968  member:  46
#  1961  member:  6
# Processing year:  1963  member:  10
# value of djf_mean:  137.36719
# Processing year:  1998  member:  Processing year:  1961  member:  6
# 27
# Processing year:  1964  member:  Processing year:  1972  member:  33
# 31
# shape of djf_mean:  ()
# value of djf_mean:  -299.93228
# value of djf_mean:  -1182.4949
# value of djf_mean:  69.890625
# value of djf_mean:  781.01306
# value of djf_mean:  522.9808
# value of djf_mean:  534.03937
# Processing year:  1969  member:  30
# shape of djf_mean:  ()
# value of djf_mean:  -1036.2471
# value of djf_mean:  value of djf_mean:  1144.1371
# value of djf_mean: 972.27734
#  1288.4519
# value of djf_mean:  -1808.4912
# Processing year:  1992  member:  49
# Processing year:  1903  member:  18
# Processing year:  1951  member:  10
# value of djf_mean:  -681.8385
# value of djf_mean:  1100.9734
# value of djf_mean:  276.5104
# value of djf_mean:  6.3450623
# value of djf_mean:  -492.94302
# shape of djf_mean:  ()shape of djf_mean:
#  shape of djf_mean:  ()
# ()
# shape of djf_mean:  ()
# value of djf_mean:  -660.44885
# value of djf_mean:  150.72884
# value of djf_mean:  1503.1664
# value of djf_mean:  140.77734
# value of djf_mean:  -269.66016
# value of djf_mean:  value of djf_mean:  711.361
# -735.5504
# value of djf_mean:  711.2119
# shape of djf_mean:  ()
# value of djf_mean:  443.71518
# value of djf_mean:  -1776.9502
# shape of djf_mean:  ()shape of djf_mean:  ()
#
# value of djf_mean:  618.70996
# Processing year:  1982  member:  7
# Processing year: Processing year:   1944  member:  1962shape of djf_mean:  ()5
#
#   member:  25
# Processing year:  1951  member:  6
# Processing year: Processing year:  1978  member:  1973  member:   22
# 14
# value of djf_mean: value of djf_mean:  210.86426
#  -2004.6707
# value of djf_mean:  77.47005
# value of djf_mean:  -287.9515
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# value of djf_mean:  -706.5251
# value of djf_mean:  -316.7956
# value of djf_mean:  124.79851
# value of djf_mean:  794.9365
# value of djf_mean:  28.939777
# value of djf_mean:  -1240.2869
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year: Processing year:   1912  member: Processing year:  1954 Processing year:   19851922  member:  41
#  member:  30
#   member:  16
# 8
# value of djf_mean:  492.4134
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1996  member: Processing year:   23
# 1950  member:  30
# Processing year:  1948  member:  24
# Processing year:  2005  member:  14
# shape of djf_mean:  ()
# Processing year:  1902  member:  30
# shape of djf_mean:  ()
# Processing year:  1993  member:  5
# shape of djf_mean:  ()
# shape of djf_mean: shape of djf_mean:  ()
# shape of djf_mean:  ()
# value of djf_mean:  991.3909
#  ()
# value of djf_mean:  -1313.2991
# value of djf_mean:  -14.643229
# value of djf_mean:  -328.75195
# Processing year:  1922  member:  48
# Processing year:  1933  member:  32Processing year:
# 1997  member:  48
# Processing year:  1969  member:  28
# ()
# shape of djf_mean:  ()
# value of djf_mean:  1237.7649
# value of djf_mean:  161.89453
# value of djf_mean:  -447.17255
# Processing year:  1966  member:  3
# shape of djf_mean:  ()
# Processing year:  1975  member:  43
# shape of djf_mean:  ()
# Processing year: Processing year:  Processing year:  1973  member:  1920  member:   30
# 9
# 2005  member:  35
# shape of djf_mean:  ()
# Processing year:  1946  member:  48
# shape of djf_mean:  ()
# value of djf_mean:  -719.4125
# value of djf_mean:  214.80405
# value of djf_mean:  -838.93976
# value of djf_mean:  -399.66602
# Processing year:  1990  member:  3
# Processing year: Processing year:  1975  member:   1991  member:  214
# Processing year:
#  1992  member:  34
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# value of djf_mean:  362.60904
# value of djf_mean:  -1225.2107
# value of djf_mean:  337.03876
# value of djf_mean:  -457.53223
# value of djf_mean:  -455.30536
# value of djf_mean:  -780.19824
# value of djf_mean:  1763.0029
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# value of djf_mean:  -186.88705
# value of djf_mean:  -1232.0156
# value of djf_mean:  825.7793
# value of djf_mean:  246.18164
# shape of djf_mean:  ()
# value of djf_mean:  735.5908
# value of djf_mean:  -415.02734
# value of djf_mean:  275.86264
# value of djf_mean:  -584.77765
# value of djf_mean:  shape of djf_mean:  ()
# -97.24869
# value of djf_mean:  -1133.9082
# value of djf_mean:  -1001.4326
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# value of djf_mean:  -93.14812
# value of djf_mean:  506.9909
# Processing year:  2009  member:  27
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year: Processing year:  1984  member:  6
#  1997 Processing year: Processing year:  member:  1
#  1929  member:  15
#  1952  member:  50
# Processing year:  1983  member:  18
# Processing year:  1992  member:  22Processing year:  1989  member:
# Processing year: 3 2001  member:
#  47
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean: value of djf_mean:  ()
#  58.807293
# value of djf_mean:  280.1071
# Processing year:  1956  member:  shape of djf_mean:  30
# ()
# value of djf_mean:  996.86163
# Processing year:  1927  member:  25
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# value of djf_mean: value of djf_mean:  -811.16766
#  -2159.2622
# value of djf_mean: value of djf_mean:  -792.67413
# value of djf_mean:  459.36035
#  687.25977value of djf_mean:  -432.1901
#
# value of djf_mean:  -661.6113
# value of djf_mean:  856.3174
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1965  member:  5
# Processing year:  1981  member:  36
# Processing year:  1982  member:  19
# Processing year:  1983  member: Processing year:  22
# Processing year:  1981  1993  member:  28
#  member:  19
# shape of djf_mean:  ()
# Processing year:  1974  member:  11
# Processing year:  1917  member:  49
# value of djf_mean:  -890.1624
# shape of djf_mean:  ()
# value of djf_mean:  -11.363602
# shape of djf_mean: value of djf_mean:  776.0928
# value of djf_mean:  1339.0244
#  ()
# value of djf_mean: value of djf_mean:  -313.223
#  208.01692
# Processing year:  1994  member:  10
# value of djf_mean: value of djf_mean:   714.70245
# -634.81384
# value of djf_mean:  -859.3047
# value of djf_mean:  -1409.7092
# value of djf_mean:  19.424484
# value of djf_mean:  118.51987
# value of djf_mean:  492.93002
# value of djf_mean:  -471.46744
# value of djf_mean:  217.10382
# value of djf_mean:  972.7155
# value of djf_mean:  -1.3401794
# value of djf_mean:  705.2347
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1997  member:  27
# value of djf_mean:  820.56964
# Processing year:  1975  member:  2
# value of djf_mean: Processing year:  Processing year:  2008  member: 1910  member:  34
#  33value of djf_mean:  1643.8955
#
#  -1596.5668
# Processing year:  1958  member:  19
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1915  member:  6
# Processing year:  1959  member:  19
# shape of djf_mean:  ()
# Processing year: Processing year: Processing year:  1965  1904  member:  20
#  1979 Processing year:  member:  17
#  member:  1920 23  member:
#  48
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1994  member:  14
# Processing year:  2001  member:  46
# shape of djf_mean:  ()
# Processing year:  1930  member:  31
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year: Processing year:   1923  member: 2004   member:  43
# 30
# value of djf_mean:  624.3096
# shape of djf_mean:  ()
# Processing year:  Processing year: 1947  member:  45
#  1988  member:  20
# Processing year:  1963  member:  44
# Processing year:  1934  member:  25
# value of djf_mean:  220.55533
# value of djf_mean:  918.30695
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# value of djf_mean:  689.1126
# value of djf_mean:  152.5
# value of djf_mean:  -1644.5828
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# value of djf_mean:  1163.741
# shape of djf_mean:  ()
# value of djf_mean:  -151.74673
# shape of djf_mean: value of djf_mean:  ()
# value of djf_mean:  1151.8232
#  -112.506836
# value of djf_mean:  -1472.5146
# shape of djf_mean:  ()
# Processing year:  1971  member:  3
# Processing year: Processing year:  1917  member:   1939  member:  17
# 18
# Processing year:  1968  member:  14
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# value of djf_mean:  191.64258
# value of djf_mean:  780.88544
# value of djf_mean:  -602.5791
# value of djf_mean:  214.46875
# Processing year: Processing year:  1907  member:  1949  29
#  member:  38
# shape of djf_mean:  ()
# value of djf_mean:  -1127.3912
# value of djf_mean:  shape of djf_mean: 2.6796875
#  ()
# shape of djf_mean: value of djf_mean: shape of djf_mean:  -114.36459
#  value of djf_mean: ()
#  1094.7871
#  ()
# value of djf_mean:  1264.8611
# value of djf_mean:  -201.3903
# value of djf_mean:  494.9069
# value of djf_mean:  -979.15265
# Processing year:  1969 value of djf_mean:  member:  40
# shape of djf_mean:  -770.874
#  ()
# Processing year:  shape of djf_mean: 1911  ()
# Processing year: Processing year:   member:  46
# 1926  member: value of djf_mean:   1415.34831998  member:
#  23
#  31
# value of djf_mean:  shape of djf_mean:  ()
# value of djf_mean:  874.8154
# value of djf_mean:  -155.125
# value of djf_mean:  506.6439
# value of djf_mean:  -15.269852
# shape of djf_mean:  ()
# shape of djf_mean:  ()value of djf_mean:  -972.8168
# value of djf_mean:  485.1605
#
# value of djf_mean:  1192.9912
# value of djf_mean:  -1030.2087
# value of djf_mean:  -397.8037
# shape of djf_mean:  ()
# shape of djf_mean:  ()Processing year:
# value of djf_mean:  269.62143
# value of djf_mean:  1285.865
# value of djf_mean:  1990  member:  6
# value of djf_mean:   219.83691
# 741.44275
# Processing year:  1931  member:  Processing year:  1936  member:  16
# 14
# Processing year:  1961  member:  17
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1955  member:  46
# Processing year: Processing year:  1917  member:  7
#  1950  member:  41
# Processing year: Processing year:  1969  1938 member: shape of djf_mean:  32
#   member:  46
#  ()
# value of djf_mean:  -487.3994
# value of djf_mean:  -2246.2007
# value of djf_mean:  362.3499
# value of djf_mean:  -6.489914
# value of djf_mean:  -223.84114
# value of djf_mean:  -418.68164
# shape of djf_mean: value of djf_mean:  ()
#  227.8024
# value of djf_mean:  865.6165
# Processing year:  1953  member:  27
# Processing year:  1965  member:  26
# 682.9401value of djf_mean:  -401.1888
#
# value of djf_mean:  -830.4424
# value of djf_mean:  2.4612656
# Processing year: Processing year:  1967  member:   1927 34 member:
# 35
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# value of djf_mean:  677.3083
# value of djf_mean:  -830.5706
# value of djf_mean:  149.80566
# shape of djf_mean:  value of djf_mean: ()
#  shape of djf_mean:  ()
# -712.39777
# value of djf_mean:  -519.53546
# value of djf_mean:  -487.2754
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1999  member:  14
# Processing year:  1963  member: Processing year:  34
# Processing year:  1951  member:   1933  member: 48
#  4
# shape of djf_mean:  ()
# value of djf_mean:  -345.95148
# value of djf_mean:  -65.77051
# value of djf_mean:  798.4346
# Processing year:  1909  member:  13
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  2001  member:  35
# shape of djf_mean: Processing year:  1982  ()
#  member:  45
# Processing year:  2003  member:  19
# Processing year: Processing year:  1995  member:  10
# 1954  member:  3
# value of djf_mean:  344.3353
# value of djf_mean:  -1211.908
# value of djf_mean:  560.1758
# Processing year:  1913  member:  33
# Processing year:  1963  member:  20
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# value of djf_mean: value of djf_mean:  -59.780914
# value of djf_mean:   690.5117
# -636.6029
# value of djf_mean: value of djf_mean:  -1261.1687 413.4388
#
# value of djf_mean: value of djf_mean:  -5.2796226
#  -148.30013
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# value of djf_mean:  -994.7591
# Processing year:  1971  member:  26
# shape of djf_mean:  ()
# value of djf_mean:  1133.1605
# shape of djf_mean:  ()
# shape of djf_mean:  shape of djf_mean: ()
#  ()
# value of djf_mean:  -175.59995
# shape of djf_mean:  ()
# value of djf_mean:  519.904
# Processing year: Processing year:  1963  member:  38
#  1944  member:  49
# Processing year: Processing year:  1979  1912  member:  31
#  member:  27
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# value of djf_mean: value of djf_mean:  892.2503
#  1778.1354
# value of djf_mean: value of djf_mean: value of djf_mean:   964.99475
# -3.1276093
#  -1667.4021
# value of djf_mean:  333.9746value of djf_mean:
# 733.7995
# Processing year:  1904  member:  1
# shape of djf_mean:  ()
# Processing year: Processing year:  2006  member:   1986 36
#  member:  25
# Processing year: Processing year:   1951 1903  member:  member:  2
# Processing year:  1915  member:  46
#  28
# Processing year:  1985  member:  24
# Processing year:  1904  member:  20
# Processing year:  1977  member:  19
# Processing year:  1955  member:  42
# value of djf_mean:  329.02768
# value of djf_mean:  1491.3932
# value of djf_mean: Processing year:  1944   member: 810.0837
#  22
# Processing year:  1934  member:  43
# Processing year:  1966  member:  8
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# value of djf_mean:  416.68036
# shape of djf_mean: value of djf_mean:  -743.45935
#  ()value of djf_mean:
#  610.9105
# value of djf_mean:  54.97397
# Processing year:  1981  member:  49
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# value of djf_mean:  501.77768
# Processing year:  1949 Processing year:  member:   19
# 1974  member:  36
# Processing year:  1934  member:  17
# Processing year:  1993  member:  45
# shape of djf_mean: shape of djf_mean:  ()
#  ()
# value of djf_mean: value of djf_mean:  -1131.0938
#  -26.138021
# value of djf_mean:  -685.7787
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1985  member:  23
# Processing year: shape of djf_mean:  1962  member:  4
#  ()
# Processing year:  1985 Processing year:  member:  20
#  1976  member:  22
# Processing year:  1923  member:  30
# Processing year:  2001  member:  26
# shape of djf_mean:  ()
# Processing year:  1963  member:  22
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# value of djf_mean:  977.6572
# value of djf_mean:  309.68945
# value of djf_mean:  -1621.7422
# value of djf_mean:  1753.0287
# value of djf_mean:  63.176758
# shape of djf_mean: Processing year:  1984  member:  46
#  ()
# value of djf_mean:  -76.515945
# shape of djf_mean:  ()
# value of djf_mean:  567.16956
# value of djf_mean:  790.52374
# value of djf_mean:  434.01953
# shape of djf_mean: value of djf_mean:  -1400.3137
#  value of djf_mean:  209.2474
# ()
# value of djf_mean:  -438.83984
# value of djf_mean:  833.20764
# value of djf_mean:  1090.7219
# shape of djf_mean:  ()
# value of djf_mean:  91.896484
# shape of djf_mean:  ()
# Processing year:  1969  member:  34Processing year:  1918  member:
#  39
# Processing year:  1923  member:  22
# Processing year:  1993  member:  36
# shape of djf_mean:  ()
# value of djf_mean:  1452.1555
# Processing year:  1999  member:  36
# shape of djf_mean:  ()
# value of djf_mean:  107.06445
# shape of djf_mean: shape of djf_mean:  ()
#  ()
# value of djf_mean:  -754.6087
# Processing year:  1913  member:  28
# Processing year:  1902  member:  32
# shape of djf_mean:  ()
# Processing year:  1986  member:  27
# shape of djf_mean: shape of djf_mean:  ()
#  ()
# Processing year:  1987  member:  50
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year: Processing year:  1995  member:  40 1979  member:
#  50
# Processing year:  1966  member:  26
# shape of djf_mean:  ()
# Processing year:  1942  member:  32
# shape of djf_mean:  ()
# value of djf_mean:  273.8626
# shape of djf_mean:  ()
# Processing year:  1970  member:  23
# value of djf_mean:  464.82422
# Processing year:  1929  member:  40
# shape of djf_mean:  ()
# Processing year:  1939  member:  34
# Processing year:  1933  member:  44
# shape of djf_mean:  ()
# shape of djf_mean: shape of djf_mean:  ()
#  ()
# Processing year: Processing year:  2000  member:   321989
#  member:  29
# shape of djf_mean:  ()
# Processing year:  1943  member:  38
# value of djf_mean:  -926.9671
# shape of djf_mean:  ()
# value of djf_mean:  -1774.1135
# Processing year:  1904 Processing year:  member:   1983 35
#  member:  29
# value of djf_mean:  61.493813
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# value of djf_mean:  -599.77795
# value of djf_mean:  1069.9662
# Processing year:  1988  member:  36
# shape of djf_mean:  ()
# Processing year:  1909  member:  23
# shape of djf_mean:  ()
# Processing year:  1909  member:  6
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1992  member:  39
# Processing year:  1967  member:  23
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# value of djf_mean:  1422.0928
# value of djf_mean:  value of djf_mean: -268.3763
#  300.3229
# Processing year:  value of djf_mean:  401.39127
# 1995  member:  9
# value of djf_mean:  -2081.7593
# value of djf_mean:  268.44794
# shape of djf_mean:  ()
# Processing year:  1995  member:  7
# shape of djf_mean:  ()
# shape of djf_mean: shape of djf_mean:  ()
#  ()
# shape of djf_mean:  ()
# Processing year:  1982  member:  47
# Processing year:  1958  member:  16
# Processing year:  2003 Processing year:  1975  member:  member:   29
# 2
# Processing year:  1918  member:  16
# shape of djf_mean:  ()
# value of djf_mean:  317.59116
# value of djf_mean:  shape of djf_mean:  ()
# -52.61914
# value of djf_mean:  -526.5924
# value of djf_mean:  652.6205
# value of djf_mean:  -246.02766
# value of djf_mean:  585.48145
# Processing year:  1988  member:  10
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1965  member:  9
# shape of djf_mean:  ()
# value of djf_mean:  -790.74866
# Processing year:  1953  member:  16
# shape of djf_mean:  ()
# value of djf_mean:  653.43066
# Processing year:  1968 Processing year:  1945Processing year:  1935   member:  member:   member:  5
# 2925
#
# shape of djf_mean:  shape of djf_mean:  ()
# Processing year:  1904  member:  6
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean: Processing year:  1935  member:  12 ()
#
# Processing year:  1990  member:  48
# Processing year:  1976  member:  49
# shape of djf_mean:  ()
# shape of djf_mean: shape of djf_mean:  ()
#  ()
# shape of djf_mean:  ()
# shape of djf_mean: ()
#  ()
# value of djf_mean:  -988.36816
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1922  member:  36
# Processing year: Processing year:  2001  member:  1924  member:   14
# 36
# shape of djf_mean:  ()
# value of djf_mean:  -330.33856
# value of djf_mean:  -710.79724
# Processing year:  1988  member:  35
# value of djf_mean:  -490.14972
# value of djf_mean:  924.45605
# Processing year:  1901  member:  21
# Processing year: Processing year:   1965  member:  1988  member:  1
# 42
# shape of djf_mean:  ()
# shape of djf_mean: value of djf_mean:   234.431
# shape of djf_mean: ()
#  ()
# value of djf_mean:  -823.8457
# shape of djf_mean:  ()
# value of djf_mean:  -487.50098
# shape of djf_mean:  ()
# value of djf_mean:  -1489.2344
# value of djf_mean:  -681.609
# value of djf_mean:  -1078.633
# value of djf_mean:  -383.65073
# value of djf_mean:  1030.823
# shape of djf_mean:  ()
# value of djf_mean:  -132.74348
# Processing year:  1984  member:  20
# shape of djf_mean:  ()
# Processing year:  1994  member:  5
# Processing year: Processing year:  1968  member: Processing year:  1969  member:  2006  24
#  member:  18
#  45
# shape of djf_mean:  ()
# value of djf_mean:  -714.2409
# value of djf_mean:  -147.77017
# value of djf_mean:  -1417.407
# value of djf_mean:  -789.3161
# Processing year:  2004  member:  19
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1966  member:  29
# Processing year:  1965  member:  23
# shape of djf_mean:  ()
# Processing year:  1944  member:  46
# shape of djf_mean:  ()
# value of djf_mean:  624.25616
# value of djf_mean:  442.48306
# value of djf_mean:  197.81934
# Processing year:  1936  member:  40
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year: Processing year:  2004  member:  27
# 1981  member:  21
# Processing year:  1947  member:  5
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1901  member:  15
# Processing year:  2008  member:  1
# shape of djf_mean:  ()
# Processing year:  2009  member:  11
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# value of djf_mean:  1182.3484
# value of djf_mean:  -1044.5557
# Processing year:  1950  member:  16
# value of djf_mean:  -1451.2891
# Processing year: Processing year:  1981  1911  member:  21
#  member:  9
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1969  member:  50
# Processing year:  1914  member:  23
# shape of djf_mean:  ()
# Processing year:  1987  member:  22
# Processing year:  1996  member:  42
# shape of djf_mean:  ()
# Processing year:  1950  member:  35
# shape of djf_mean:  ()
# Processing year:  1937  member:  3
# shape of djf_mean:  ()
# Processing year:  1948  member:  19
# shape of djf_mean:  ()
# Processing year:  1985  member:  45
# shape of djf_mean:  ()
# value of djf_mean:  shape of djf_mean:  ()
# -1075.5305
# value of djf_mean:  -42.364258
# Processing year:  1948  member:  38
# shape of djf_mean:  Processing year:  1940  member:  31
# ()
# shape of djf_mean:  ()
# Processing year:  1987  member:  34
# Processing year:  1917  member:  16
# Processing year:  1931  member: Processing year:  10
#  1901  member:  35
# shape of djf_mean:  ()
# Processing year:  2006  member:  49
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# value of djf_mean:  525.14355
# Processing year: Processing year:  1922   member: 1962  member:  20
#  22
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  2006  member:  16
# Processing year:  1960  member:  48
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year: Processing year:   1957  member:  4
# 1961  member:  49
# Processing year:  1919  member:  19
# Processing year:  1910  member:  16
# Processing year: Processing year:  1909  1911  member:  47
#  member:  14
# Processing year:  1963  member:  31
# Processing year:  1946  member:  9
# Processing year:  1947  member:  8
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1952  member:  42
# Processing year:  1983  member:  49
# shape of djf_mean:  ()
# Processing year:  1996  member:  8
# shape of djf_mean:  ()
# value of djf_mean:  -391.43033
# value of djf_mean:  891.6556
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1990  member:  41
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# value of djf_mean:  -214.62173
# value of djf_mean:  793.5674
# value of djf_mean:  1391.79
# value of djf_mean:  Processing year:  1961  member:  355.19107
# 12
# value of djf_mean:  201.29102
# value of djf_mean:  -68.2347
# value of djf_mean:  185.5664
# shape of djf_mean:  ()
# value of djf_mean:  251.7539
# value of djf_mean:  1231.9043
# value of djf_mean:  -876.7754
# value of djf_mean:  -367.18423
# value of djf_mean:  -2082.1787
# value of djf_mean:  410.35156
# Processing year:  1982  member:  36
# Processing year:  1959  member:  16
# Processing year:  Processing year:  1942  member: 1930  member:  21
#  43
# shape of djf_mean:  ()
# value of djf_mean:  -729.4548
# value of djf_mean:  65.86719
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# value of djf_mean:  969.3916
# value of djf_mean:  -605.0078
# value of djf_mean:  207.24219
# value of djf_mean:  1784.7588
# value of djf_mean:  -1231.8914
# value of djf_mean:  333.10678
# value of djf_mean:  -361.42056
# value of djf_mean:  1475.709
# value of djf_mean:  -388.60873
# shape of djf_mean:  Processing year:  1938  member:  32
# shape of djf_mean: ()
#  ()
# value of djf_mean:  -488.26596
# Processing year:  1998  member:  23
# Processing year:  1954  member:  42
# shape of djf_mean: shape of djf_mean:  () ()
#
# value of djf_mean:  -36.049484
# value of djf_mean:  268.3838
# value of djf_mean:  -1379.0017value of djf_mean:
#  value of djf_mean:  663.79333
# -675.2162
# value of djf_mean:  -1325.4099
# value of djf_mean:  807.25653
# value of djf_mean:  -611.4935
# Processing year:  1960  member: Processing year:  1997  member:  17 37
#
# shape of djf_mean:  ()
# Processing year:  2000  member:  21
# shape of djf_mean:  ()
# Processing year:  1955  member:  34
# shape of djf_mean:  ()
# Processing year:  1952  member:  49
# Processing year:  1908  member:  22
# shape of djf_mean:  ()
# Processing year:  1944  member:  7
# shape of djf_mean:  ()
# value of djf_mean:  -1013.26306
# value of djf_mean:  -610.6198
# value of djf_mean:  267.4749
# value of djf_mean:  668.0016
# Processing year:  1956  member:  19
# shape of djf_mean:  ()
# Processing year:  1915  member:  15
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean: shape of djf_mean:  ()
#  ()
# Processing year:  1979 Processing year:  member:  20
#  1980  member:  45
# shape of djf_mean:  ()
# value of djf_mean:  20.500656
# value of djf_mean:  -485.18945
# value of djf_mean:  -653.99255
# value of djf_mean:  674.4258
# value of djf_mean:  753.0049
# value of djf_mean:  -561.09607
# value of djf_mean:  1034.8604
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1916  member:  48
# value of djf_mean: value of djf_mean:  1219.7395
# value of djf_mean:  626.5836
#  492.6416
# value of djf_mean:  -52.01172
# value of djf_mean:  1281.7441
# shape of djf_mean: shape of djf_mean:   ()
# ()
# Processing year: shape of djf_mean:  ()
#  1939  member:  33
# shape of djf_mean:  ()
# Processing year:  1980  member:  34
# shape of djf_mean:  ()
# Processing year:  Processing year:  Processing year: 19151956  member:    member: 50
#   29
# Processing year:  1956  member:  24
# 1947  member:  3
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1960  member:  25
# Processing year:  1908  member:  11
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1992  member:  46
# Processing year:  2005  member:  30
# Processing year:  1914  member:  18
# Processing year:  1967  member:  26
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1977  member:  1
# shape of djf_mean:  ()
# Processing year:  2009  member:  18
# value of djf_mean:  483.46225
# value of djf_mean:  -231.20834
# value of djf_mean:  859.208
# shape of djf_mean:  ()
# value of djf_mean:  164.15103
# value of djf_mean:  179.3646
# value of djf_mean:  366.06543
# value of djf_mean:  519.80927
# shape of djf_mean:  value of djf_mean:  -295.04034
# ()
# Processing year:  2007  member:  40
# value of djf_mean:  -534.52734
# value of djf_mean:  268.62598
# Processing year:  1966  member:  28
# Processing year:  1984  member:  10
# shape of djf_mean:  ()
# Processing year:  1953  member:  35
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1947  member:  11
# shape of djf_mean:  ()
# Processing year:  1961  member:  18
# Processing year:  1928  member:  48
# value of djf_mean:  253.42122
# value of djf_mean:  214.02051
# Processing year:  1941  member:  35
# value of djf_mean:  59.54883
# value of djf_mean:  831.613
# value of djf_mean:  445.847
# Processing year: Processing year: Processing year:  1939   member:  14
# 1936   member: 1910  9
#  member:  20
# Processing year:  1911  member:  3
# Processing year:  2005  member:  44
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# shape of djf_mean:  ()
# Processing year:  1935  member:  48
# ...
# result 5337 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5338 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5339 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5340 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5341 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5342 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5343 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5344 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5345 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5346 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5347 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5348 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5349 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5350 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5351 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5352 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5353 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5354 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5355 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5356 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5357 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5358 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5359 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5360 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5361 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5362 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5363 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5364 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5365 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5366 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5367 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5368 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5369 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5370 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5371 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5372 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5373 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5374 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5375 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5376 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5377 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5378 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5379 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5380 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5381 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5382 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5383 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5384 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5385 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5386 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5387 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5388 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5389 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5390 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5391 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5392 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5393 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5394 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5395 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5396 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5397 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5398 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5399 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5400 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5401 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5402 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5403 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5404 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5405 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5406 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5407 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5408 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5409 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5410 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5411 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5412 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5413 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5414 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5415 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5416 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5417 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5418 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5419 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5420 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5421 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5422 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5423 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5424 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5425 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5426 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5427 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5428 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5429 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5430 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5431 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5432 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5433 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5434 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5435 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5436 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5437 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5438 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5439 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5440 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5441 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5442 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5443 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5444 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5445 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5446 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5447 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5448 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# result 5449 has value:  <xarray.DataArray 'MSL_GDS0_SFC' ()>
# dask.array<sub, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# (109, 50)

# %%
test_dask_array
# Out:
# dask.array<setitem, shape=(109, 50), dtype=float64, chunksize=(109, 50), chunktype=numpy.ndarray>

# %%
# # TODO: We want to take the 8 year running mean of this array
# # Print the dask array
# print(test_dask_array.compute())

# %%
# Extract the data
asf20c_nao = test_dask_array.compute()

# %%
print(asf20c_nao.shape)

# Create an empty array to store the results
asf20c_nao_rm = np.empty([len(years) - 7, len(members)])

# Set up the window
window = np.ones(8) / 8

# Loop through the members
for member in members:
    # Loop through the years
    for year in years[:-7]:
        # Set the year index
        year_index = year - 1901

        # Set the member index
        member_index = member - 1

        # Set the data
        data = asf20c_nao[year_index : year_index + 8, member_index]

        # Compute the 8 year running mean
        asf20c_nao_rm[year_index, member_index] = np.convolve(data, window, mode="valid")

# Forward running mean of the data
# from 1901 to 2010 - 7
# from 1901 to 2003
rm_years_asf20c = years[:-7]

# Print the shape of the data
print(asf20c_nao_rm.shape)
print(rm_years_asf20c.shape)

# Print the data
print(asf20c_nao)
# Out:
# (109, 50)
# (102, 50)
# (102,)
# [[-1528.01599121   -69.77832031 -1487.66113281 ...  -239.04067993
#   -1174.47436523    14.56477928]
#  [  333.49966431  -551.34277344   618.56085205 ...  -673.24902344
#    -469.92449951   832.94372559]
#  [ -445.51922607   -87.08236694   -86.64877319 ...  -201.67254639
#     273.86260986   424.83465576]
#  ...
#  [ -107.10481262  -489.47949219   -29.06381226 ...   267.47491455
#     197.81933594 -1270.49731445]
#  [  735.36486816   865.99414062  -906.84863281 ...   877.98797607
#     452.72036743  -305.16210938]
#  [-1045.35583496   139.72331238 -1813.19702148 ...   335.52700806
#    -316.64746094  1070.78186035]]

# %%
# Import local dictionaries and functions
sys.path.append('/home/users/benhutch/skill-maps')

# Import dictionaries
import dictionaries as dic

# Set up the path where the functions are stored
sys.path.append('/home/users/benhutch/skill-maps/python')

# Import functions
import functions as func

# Import the NAO skill functions
import nao_skill_functions as nao_func

# Set up the path where the functions are stored
sys.path.append('/home/users/benhutch/skill-maps/rose-suite-matching')

# Import the suite functions
import nao_matching_seasons as nms_func

# Import the bootstrapping functions
import process_bs_values as pbs_func

# %%
# Find the psl field data
# Set up the base path
base_path_canari = "/gws/nopw/j04/canari/users/benhutch"

# File name
file_name = "adaptor.mars.internal-1703255460.0952423-14259-18-80988a8a-51a2-4138-9b16-41a188e1c9d8.grib"

# Form a new path
new_path_ERA5 = os.path.join(base_path_canari, "ERA5", file_name)

# Check if the file exists
if os.path.exists(new_path_ERA5):
    print(f"The file {new_path_ERA5} exists")

# Setup a directory for the regridded data
regrid_dir = os.path.join(base_path_canari, "ERA5", "regrid")

# Check if the directory exists
if not os.path.exists(regrid_dir):
    print(f"The directory {regrid_dir} does not exist")
    # Create a new directory
    os.makedirs(regrid_dir, exist_ok=False)

# Set up the output file name
output_file = os.path.join(regrid_dir, f"{file_name[:-5]}_rg.grib")

# # Print the output file name
# print(output_file)

# Set up the gridspec file
gridspec_file = os.path.join(gridspec_dir, "gridspec-global.txt")

# Check if the file exists
if os.path.exists(gridspec_file):
    print(f"The file {gridspec_file} exists")

# Only if the output file does not exist
if not os.path.exists(output_file):
    print(f"The file {output_file} does not exist")

    # Regrid the file
    cdo.remapbil(gridspec_file, input=new_path_ERA5, output=output_file)

# Find the file ending with _rg.nc in the regrid directory
# List the files in the directory
print(os.listdir(regrid_dir))

# Find the file ending with _rg.nc
files = os.listdir(regrid_dir)

# Loop through the files
psl_obs = [file for file in files if file.endswith("_rg.nc")]

# Print the files
print(psl_obs)

# Form the full path
psl_obs = os.path.join(regrid_dir, psl_obs[0])

# Extract using xarray
psl_obs = xr.open_dataset(
    psl_obs, chunks={"time": 100, "lat": 100, "lon": 100}
)

# Extract the months of December, January and February
psl_obs_djf = psl_obs.sel(time=psl_obs["time.season"] == "DJF")

# Calculate the mean over the time dimension - the climatology
psl_obs_djf_mean = psl_obs_djf.mean(dim="time")

# Remove the mean from the data
psl_obs_djf_anom = psl_obs_djf - psl_obs_djf_mean

# psl_obs_djf_anom

# Shift the time back by -2 and take the annual mean
# to get the annual DJF mean
psl_obs_djf_anom = psl_obs_djf_anom.shift(time=-2).resample(time="Y").mean(dim="time")

# Now take the rolling mean over 8 years
psl_obs_djf_anom = psl_obs_djf_anom.rolling(time=8, center=True).mean()

# Calculate the NAO index
# Extract the lats and lons for the NAO region
iceland_lat1, iceland_lat2 = (
    dic.iceland_grid_corrected["lat1"],
    dic.iceland_grid_corrected["lat2"],
)
iceland_lon1, iceland_lon2 = (
    dic.iceland_grid_corrected["lon1"],
    dic.iceland_grid_corrected["lon2"],
)

# And for the azores
azores_lat1, azores_lat2 = (
    dic.azores_grid_corrected["lat1"],
    dic.azores_grid_corrected["lat2"],
)
azores_lon1, azores_lon2 = (
    dic.azores_grid_corrected["lon1"],
    dic.azores_grid_corrected["lon2"],
)

# Take the mean over the spatial dimension of the iceland gridbox
iceland_mean = (
    psl_obs_djf_anom["var151"]
    .sel(
        lat=slice(iceland_lat1, iceland_lat2),
        lon=slice(iceland_lon1, iceland_lon2),
    )
    .mean(axis=(1, 2))
)

# Take the mean over the spatial dimension of the azores gridbox
azores_mean = (
    psl_obs_djf_anom["var151"]
    .sel(
        lat=slice(azores_lat1, azores_lat2),
        lon=slice(azores_lon1, azores_lon2),
    )
    .mean(axis=(1, 2))
)

# Calculate the NAO index
nao_index = azores_mean - iceland_mean

# Print the shape of the data
print("shape of nao_index: ", nao_index.shape)

# Print the data
print(nao_index)
# Out:
# The file /gws/nopw/j04/canari/users/benhutch/ERA5/adaptor.mars.internal-1703255460.0952423-14259-18-80988a8a-51a2-4138-9b16-41a188e1c9d8.grib exists
# The file /home/users/benhutch/gridspec/gridspec-global.txt exists
# ['adaptor.mars.internal-1703255460.0952423-14259-18-80988a8a-51a2-4138-9b16-41a188e1c9d8_rg.grib', 'adaptor.mars.internal-1703255460.0952423-14259-18-80988a8a-51a2-4138-9b16-41a188e1c9d8_rg.nc']
# ['adaptor.mars.internal-1703255460.0952423-14259-18-80988a8a-51a2-4138-9b16-41a188e1c9d8_rg.nc']
# shape of nao_index:  (84,)
# <xarray.DataArray 'var151' (time: 84)>
# dask.array<sub, shape=(84,), dtype=float64, chunksize=(8,), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 1940-12-31 1941-12-31 ... 2023-12-31

# %% [markdown]
# ## DCPP ##
#
# We also want to load the DCPP data as a comparison. We'll do this below and plot against the long ERA5 obs for comparison.

# %%
# Set up the arguments for extracting the DCPP model data
psl_models = dic.models
obs_path_psl = dic.obs
base_dir = dic.base_dir
plots_dir = "/gws/nopw/j04/canari/users/benhutch/plots/NAO_skill"
save_dir = dic.save_dir
global_grid = dic.gridspec_global
psl_var_name = "psl"

# %%
# Process the global psl anomalies to be used for the NAO index
obs_psl_anom_short = func.read_obs(variable='psl',
                            region='global',
                            forecast_range='2-9',
                            season="DJFM",
                            observations_path=obs_path_psl,
                            start_year=1960,
                            end_year=2023)
# Out:
# Time dimension of obs: ['1960-12-31T00:00:00.000000000' '1961-12-31T00:00:00.000000000'
#  '1962-12-31T00:00:00.000000000' '1963-12-31T00:00:00.000000000'
#  '1964-12-31T00:00:00.000000000' '1965-12-31T00:00:00.000000000'
#  '1966-12-31T00:00:00.000000000' '1967-12-31T00:00:00.000000000'
#  '1968-12-31T00:00:00.000000000' '1969-12-31T00:00:00.000000000'
#  '1970-12-31T00:00:00.000000000' '1971-12-31T00:00:00.000000000'
#  '1972-12-31T00:00:00.000000000' '1973-12-31T00:00:00.000000000'
#  '1974-12-31T00:00:00.000000000' '1975-12-31T00:00:00.000000000'
#  '1976-12-31T00:00:00.000000000' '1977-12-31T00:00:00.000000000'
#  '1978-12-31T00:00:00.000000000' '1979-12-31T00:00:00.000000000'
#  '1980-12-31T00:00:00.000000000' '1981-12-31T00:00:00.000000000'
#  '1982-12-31T00:00:00.000000000' '1983-12-31T00:00:00.000000000'
#  '1984-12-31T00:00:00.000000000' '1985-12-31T00:00:00.000000000'
#  '1986-12-31T00:00:00.000000000' '1987-12-31T00:00:00.000000000'
#  '1988-12-31T00:00:00.000000000' '1989-12-31T00:00:00.000000000'
#  '1990-12-31T00:00:00.000000000' '1991-12-31T00:00:00.000000000'
#  '1992-12-31T00:00:00.000000000' '1993-12-31T00:00:00.000000000'
#  '1994-12-31T00:00:00.000000000' '1995-12-31T00:00:00.000000000'
#  '1996-12-31T00:00:00.000000000' '1997-12-31T00:00:00.000000000'
#  '1998-12-31T00:00:00.000000000' '1999-12-31T00:00:00.000000000'
#  '2000-12-31T00:00:00.000000000' '2001-12-31T00:00:00.000000000'
#  '2002-12-31T00:00:00.000000000' '2003-12-31T00:00:00.000000000'
#  '2004-12-31T00:00:00.000000000' '2005-12-31T00:00:00.000000000'
#  '2006-12-31T00:00:00.000000000' '2007-12-31T00:00:00.000000000'
#  '2008-12-31T00:00:00.000000000' '2009-12-31T00:00:00.000000000'
#  '2010-12-31T00:00:00.000000000' '2011-12-31T00:00:00.000000000'
#  '2012-12-31T00:00:00.000000000' '2013-12-31T00:00:00.000000000'
#  '2014-12-31T00:00:00.000000000' '2015-12-31T00:00:00.000000000'
#  '2016-12-31T00:00:00.000000000' '2017-12-31T00:00:00.000000000'
#  '2018-12-31T00:00:00.000000000' '2019-12-31T00:00:00.000000000'
#  '2020-12-31T00:00:00.000000000' '2021-12-31T00:00:00.000000000'
#  '2022-12-31T00:00:00.000000000' '2023-12-31T00:00:00.000000000']
# /apps/jasmin/jaspy/miniconda_envs/jaspy3.10/m3-4.9.2/envs/jaspy3.10-m3-4.9.2-r20220721/lib/python3.10/site-packages/iris/coords.py:2220: UserWarning: Collapsing a non-contiguous coordinate. Metadata may not be fully descriptive for 'time'.
#   warnings.warn(msg.format(self.name()))

# %%
# Load and process the model psl anomalies for the NAO index
model_datasets_psl = func.load_data(base_directory=base_dir,
                                    models=psl_models,
                                    variable=psl_var_name,
                                    region='global',
                                    forecast_range='2-9',
                                    season='DJFM')

# Process the model psl anomalies
model_psl_anoms, _ = func.process_data(datasets_by_model=model_datasets_psl,
                                       variable=psl_var_name)

# %%
# Remove the years containing Nans from the short obs and model datasets
obs_psl_anom_short, \
model_psl_anoms, _ = func.remove_years_with_nans_nao(observed_data=obs_psl_anom_short,
                                                  model_data=model_psl_anoms,
                                                  models=psl_models,
                                                  NAO_matched=False)
# Out:
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# No NaN values in the model data
# 1960 all NaN values for this year
# 1961 all NaN values for this year
# 1962 all NaN values for this year
# 1963 all NaN values for this year
# 1964 no NaN values for this year
# 1965 no NaN values for this year
# 1966 no NaN values for this year
# 1967 no NaN values for this year
# 1968 no NaN values for this year
# 1969 no NaN values for this year
# 1970 no NaN values for this year
# 1971 no NaN values for this year
# 1972 no NaN values for this year
# 1973 no NaN values for this year
# 1974 no NaN values for this year
# 1975 no NaN values for this year
# 1976 no NaN values for this year
# 1977 no NaN values for this year
# 1978 no NaN values for this year
# 1979 no NaN values for this year
# 1980 no NaN values for this year
# 1981 no NaN values for this year
# 1982 no NaN values for this year
# 1983 no NaN values for this year
# 1984 no NaN values for this year
# 1985 no NaN values for this year
# 1986 no NaN values for this year
# 1987 no NaN values for this year
# 1988 no NaN values for this year
# 1989 no NaN values for this year
# 1990 no NaN values for this year
# 1991 no NaN values for this year
# 1992 no NaN values for this year
# 1993 no NaN values for this year
# 1994 no NaN values for this year
# 1995 no NaN values for this year
# 1996 no NaN values for this year
# 1997 no NaN values for this year
# 1998 no NaN values for this year
# 1999 no NaN values for this year
# 2000 no NaN values for this year
# 2001 no NaN values for this year
# 2002 no NaN values for this year
# 2003 no NaN values for this year
# 2004 no NaN values for this year
# 2005 no NaN values for this year
# 2006 no NaN values for this year
# 2007 no NaN values for this year
# 2008 no NaN values for this year
# 2009 no NaN values for this year
# 2010 no NaN values for this year
# 2011 no NaN values for this year
# 2012 no NaN values for this year
# 2013 no NaN values for this year
# 2014 no NaN values for this year
# 2015 no NaN values for this year
# 2016 no NaN values for this year
# 2017 no NaN values for this year
# 2018 no NaN values for this year
# 2019 no NaN values for this year
# 2020 all NaN values for this year
# 2021 all NaN values for this year
# 2022 all NaN values for this year
# 2023 all NaN values for this year
# obs years and model years are not the same
# Aligning the years

# %%
# Calculate the NAO stats
# test the new function
nao_stats_dict = nao_func.nao_stats(obs_psl=obs_psl_anom_short,
                        hindcast_psl=model_psl_anoms,
                        models_list=psl_models,
                        lag=4,
                        short_period=(1965, 2010),
                        season="DJFM")
# Out:
# Setting up the NAO stats for the BCC-CSM2-MR model
# model number: 0
# The years in the observations are not the same as the years in the hindcast data for the BCC-CSM2-MR model
# Obs first year: 1965
# Hindcast first year: 1966
# Obs last year: 2019
# Hindcast last year: 2019
# years checking complete for the observations and the BCC-CSM2-MR model
# years_short: [1966 1967 1968 1969 1970 1971 1972 1973 1974 1975 1976 1977 1978 1979
#  1980 1981 1982 1983 1984 1985 1986 1987 1988 1989 1990 1991 1992 1993
#  1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004 2005 2006 2007
#  2008 2009 2010]
# nao_members shape: (8, 54)
# nao_members_short shape: (8, 45)
# nao_member shape: (54,)
# nao_member_short shape: (45,)
# nao_members shape: (8, 54)
# nao_members_short shape: (8, 45)
# nao_member shape: (54,)
# nao_member_short shape: (45,)
# nao_members shape: (8, 54)
# nao_members_short shape: (8, 45)
# nao_member shape: (54,)
# nao_member_short shape: (45,)
# nao_members shape: (8, 54)
# nao_members_short shape: (8, 45)
# nao_member shape: (54,)
# nao_member_short shape: (45,)
# nao_members shape: (8, 54)
# nao_members_short shape: (8, 45)
# nao_member shape: (54,)
# nao_member_short shape: (45,)
# nao_members shape: (8, 54)
# nao_members_short shape: (8, 45)
# nao_member shape: (54,)
# nao_member_short shape: (45,)
# nao_members shape: (8, 54)
# nao_members_short shape: (8, 45)
# nao_member shape: (54,)
# nao_member_short shape: (45,)
# nao_members shape: (8, 54)
# nao_members_short shape: (8, 45)
# nao_member shape: (54,)
# nao_member_short shape: (45,)
# NAO index calculated for the BCC-CSM2-MR model
# Setting up the NAO stats for the MPI-ESM1-2-HR model
# model number: 1
# years checking complete for the observations and the MPI-ESM1-2-HR model
# years_short: [1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975 1976 1977 1978
#  1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989 1990 1991 1992
#  1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004 2005 2006
#  2007 2008 2009 2010]
# nao_members shape: (10, 55)
# nao_members_short shape: (10, 46)
# nao_member shape: (55,)
# nao_member_short shape: (46,)
# nao_members shape: (10, 55)
# nao_members_short shape: (10, 46)
# nao_member shape: (55,)
# nao_member_short shape: (46,)
# nao_members shape: (10, 55)
# nao_members_short shape: (10, 46)
# nao_member shape: (55,)
# nao_member_short shape: (46,)
# nao_members shape: (10, 55)
# nao_members_short shape: (10, 46)
# nao_member shape: (55,)
# nao_member_short shape: (46,)
# nao_members shape: (10, 55)
# nao_members_short shape: (10, 46)
# nao_member shape: (55,)
# nao_member_short shape: (46,)
# nao_members shape: (10, 55)
# nao_members_short shape: (10, 46)
# nao_member shape: (55,)
# nao_member_short shape: (46,)
# nao_members shape: (10, 55)
# nao_members_short shape: (10, 46)
# nao_member shape: (55,)
# nao_member_short shape: (46,)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /apps/jasmin/jaspy/miniconda_envs/jaspy3.10/m3-4.9.2/envs/jaspy3.10-m3-4.9.2-r20220721/lib/python3.10/site-packages/xarray/core/common.py:134, in AbstractArray.__float__(self)
#     133 def __float__(self: Any) -> float:
# --> 134     return float(self.values)
#
# File /apps/jasmin/jaspy/miniconda_envs/jaspy3.10/m3-4.9.2/envs/jaspy3.10-m3-4.9.2-r20220721/lib/python3.10/site-packages/xarray/core/dataarray.py:642, in DataArray.values(self)
#     635 """
#     636 The array's data as a numpy.ndarray.
#     637
#    (...)
#     640 type does not support coercion like this (e.g. cupy).
#     641 """
# --> 642 return self.variable.values
#
# File /apps/jasmin/jaspy/miniconda_envs/jaspy3.10/m3-4.9.2/envs/jaspy3.10-m3-4.9.2-r20220721/lib/python3.10/site-packages/xarray/core/variable.py:512, in Variable.values(self)
#     511 """The variable's data as a numpy.ndarray"""
# --> 512 return _as_array_or_item(self._data)
#
# File /apps/jasmin/jaspy/miniconda_envs/jaspy3.10/m3-4.9.2/envs/jaspy3.10-m3-4.9.2-r20220721/lib/python3.10/site-packages/xarray/core/variable.py:252, in _as_array_or_item(data)
#     239 """Return the given values as a numpy array, or as an individual item if
#     240 it's a 0d datetime64 or timedelta64 array.
#     241
#    (...)
#     250 TODO: remove this (replace with np.asarray) once these issues are fixed
#     251 """
# --> 252 data = np.asarray(data)
#     253 if data.ndim == 0:
#
# File /apps/jasmin/jaspy/miniconda_envs/jaspy3.10/m3-4.9.2/envs/jaspy3.10-m3-4.9.2-r20220721/lib/python3.10/site-packages/dask/array/core.py:1689, in Array.__array__(self, dtype, **kwargs)
#    1688 def __array__(self, dtype=None, **kwargs):
# -> 1689     x = self.compute()
#    1690     if dtype and x.dtype != dtype:
#
# File /apps/jasmin/jaspy/miniconda_envs/jaspy3.10/m3-4.9.2/envs/jaspy3.10-m3-4.9.2-r20220721/lib/python3.10/site-packages/dask/base.py:315, in DaskMethodsMixin.compute(self, **kwargs)
#     292 """Compute this dask collection
#     293
#     294 This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     313 dask.base.compute
#     314 """
# --> 315 (result,) = compute(self, traverse=False, **kwargs)
#     316 return result
#
# File /apps/jasmin/jaspy/miniconda_envs/jaspy3.10/m3-4.9.2/envs/jaspy3.10-m3-4.9.2-r20220721/lib/python3.10/site-packages/dask/base.py:603, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     601     postcomputes.append(x.__dask_postcompute__())
# --> 603 results = schedule(dsk, keys, **kwargs)
#     604 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File /apps/jasmin/jaspy/miniconda_envs/jaspy3.10/m3-4.9.2/envs/jaspy3.10-m3-4.9.2-r20220721/lib/python3.10/site-packages/distributed/client.py:3000, in Client.get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2999 try:
# -> 3000     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    3001 finally:
#
# File /apps/jasmin/jaspy/miniconda_envs/jaspy3.10/m3-4.9.2/envs/jaspy3.10-m3-4.9.2-r20220721/lib/python3.10/site-packages/distributed/client.py:2174, in Client.gather(self, futures, errors, direct, asynchronous)
#    2173     local_worker = None
# -> 2174 return self.sync(
#    2175     self._gather,
#    2176     futures,
#    2177     errors=errors,
#    2178     direct=direct,
#    2179     local_worker=local_worker,
#    2180     asynchronous=asynchronous,
#    2181 )
#
# File /apps/jasmin/jaspy/miniconda_envs/jaspy3.10/m3-4.9.2/envs/jaspy3.10-m3-4.9.2-r20220721/lib/python3.10/site-packages/distributed/utils.py:338, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     337 else:
# --> 338     return sync(
#     339         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     340     )
#
# File /apps/jasmin/jaspy/miniconda_envs/jaspy3.10/m3-4.9.2/envs/jaspy3.10-m3-4.9.2-r20220721/lib/python3.10/site-packages/distributed/utils.py:401, in sync(loop, func, callback_timeout, *args, **kwargs)
#     400     while not e.is_set():
# --> 401         wait(10)
#     403 if error:
#
# File /apps/jasmin/jaspy/miniconda_envs/jaspy3.10/m3-4.9.2/envs/jaspy3.10-m3-4.9.2-r20220721/lib/python3.10/site-packages/distributed/utils.py:390, in sync.<locals>.wait(timeout)
#     389 try:
# --> 390     return e.wait(timeout)
#     391 except KeyboardInterrupt:
#
# File /apps/jasmin/jaspy/miniconda_envs/jaspy3.10/m3-4.9.2/envs/jaspy3.10-m3-4.9.2-r20220721/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File /apps/jasmin/jaspy/miniconda_envs/jaspy3.10/m3-4.9.2/envs/jaspy3.10-m3-4.9.2-r20220721/lib/python3.10/threading.py:324, in Condition.wait(self, timeout)
#     323 if timeout > 0:
# --> 324     gotit = waiter.acquire(True, timeout)
#     325 else:
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Input In [21], in <cell line: 3>()
#       1 # Calculate the NAO stats
#       2 # test the new function
# ----> 3 nao_stats_dict = nao_func.nao_stats(obs_psl=obs_psl_anom_short,
#       4                         hindcast_psl=model_psl_anoms,
#       5                         models_list=psl_models,
#       6                         lag=4,
#       7                         short_period=(1965, 2010),
#       8                         season="DJFM")
#
# File ~/skill-maps/python/nao_skill_functions.py:812, in nao_stats(obs_psl, hindcast_psl, models_list, obs_tas, hindcast_tas, lag, short_period, season, forecast_range)
#     807     # Otherwise
#     808     else:
#     809         # Loop over the lag indices
#     810         for lag_index in range(lag):
#     811             # Calculate the lagged ensemble member
# --> 812             nao_members_lag[i + (lag_index * nens),
#     813                             year] = nao_member[year - lag_index]
#     815 # For the short period
#     816 for year in range(len(years_short)):
#     817     # If the year index is less than the lag index
#
# ValueError: setting an array element with a sequence.

# %%
# Now we need to process the individual model data
# into a multi-model mean
# Just use the raw ensemble here (~178 members)
total_nens = 0

# Set up the length of the time series for raw and lagged
nyears_short = len(np.arange(1966, 2010 + 1))
nyears_long = len(np.arange(1966, 2019 + 1))

# Set up the years
years = nao_stats_dict['BCC-CSM2-MR']['years']

# Loop through the models
for model in psl_models:
    # Extract the NAO stats for the model
    nao_stats = nao_stats_dict[model]

    # Add the number of ensemble members for this model to the total
    total_nens += nao_stats['nens']

# Create an empty array to store the ensemble members
nao_members=np.zeros([total_nens, nyears_long])

# Set up the current index
current_index = 0

# Extract the members for the raw NAO index
for model in psl_models:
    nao_stats_model = nao_stats_dict[model]

    # Loop over the members
    for i in range(nao_stats_model['nens']):
        # Extract the NAO index for this members
        nao_member = nao_stats_model['model_nao_ts_members'][i, :]

        # Set up the length of the correct time series
        nyears_BCC = len(nao_stats_dict['BCC-CSM2-MR']['years'])

        # if the model is not BCC-CSM2-MR
        if model != 'BCC-CSM2-MR':
            # Extract the length of the time series for this model
            nyears = len(nao_stats_model['years'][1:])
        else:
            # Extract the length of the time series for this model
            nyears = len(nao_stats_model['years'])

        # if these lens are not equal then we need to skip over the 0th time index
        if nyears != nyears_BCC:
            print("The length of the time series for {} is not equal to the length of the time series for BCC-CSM2-MR".format(
                model))
            
            # Figure out how many years to skip over at the end
            skip_years = nyears_BCC - nyears
            
            # Assert that the new len is correct
            assert len(nao_member[1:skip_years]) == nyears_BCC, "Length of nao_member is not equal to nyears_BCC"
        else:
            # # Assert that the new len is correct
            # assert len(nao_member) == nyears_BCC, "Length of nao_member is not equal to nyears_BCC"

            # Set skip_years to length of time series
            skip_years = len(nao_member)

        # If the model is not BCC-CSM2-MR
        # then we need to skip over the 0th time index
        if model != "BCC-CSM2-MR":
            # Append this member to the array
            nao_members[current_index, :] = nao_member[1:skip_years]
        else:
            # Append this member to the array
            nao_members[current_index, :] = nao_member

        # Increment the counter
        current_index += 1

# Print the shape of the array
print(nao_members.shape)

print(nyears_BCC)

# Print the years
print(years)

print(nao_members)

# Calculate the multi-model mean
nao_mean = np.mean(nao_members, axis=0)
# Out:
# (178, 54)
# 54
# [1966 1967 1968 1969 1970 1971 1972 1973 1974 1975 1976 1977 1978 1979
#  1980 1981 1982 1983 1984 1985 1986 1987 1988 1989 1990 1991 1992 1993
#  1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004 2005 2006 2007
#  2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019]
# [[-165.98828125   -6.11132812  330.74188232 ...  -27.24771881
#   -159.99316406  -55.70540619]
#  [ -91.21744537 -530.79785156   70.3971405  ... -243.76855469
#    265.15917969  140.12045288]
#  [ -45.57551956  157.032547    -85.90136719 ...  521.45703125
#    337.81219482  104.02506256]
#  ...
#  [-160.66862488  463.37826538  367.8359375  ...  262.81671143
#    150.89779663  -61.83235931]
#  [ 194.46452332  -15.61914062  169.36555481 ...  122.71614838
#   -363.14907837 -398.18292236]
#  [  89.94824219   52.7265625    46.06607819 ...  -90.68489075
#   -314.24414062  -32.69628906]]

# %%
# Plot both the long obs and the shorter DCPP data
long_nao_obs = nao_index

# Extract the years
long_nao_obs_years = long_nao_obs['time.year']

# Convert long_nao_obs and long_nao_obs_years to numpy arrays
long_nao_obs = long_nao_obs.values
long_nao_obs_years = long_nao_obs_years.values

# Print the shape of the data
print(long_nao_obs.shape)
print(long_nao_obs_years.shape)

# set the dcpp nao index
dcpp_nao_index = nao_mean

# Set the years for dcpp
dcpp_years = years

# Set up the ASF20C years
asf20c_years = rm_years_asf20c

# Set up the ASF20C NAO index
asf20c_nao_index = asf20c_nao_rm

# Print the shape of the data
print(dcpp_nao_index.shape)
print(dcpp_years.shape)

# Set up the figure
fig, ax = plt.subplots(figsize=(12, 6))

# Plot the long obs
ax.plot(long_nao_obs_years - 5,
        long_nao_obs / 100, color='k', label='ERA5')

# Plot the DCPP
ax.plot(dcpp_years - 5,
        dcpp_nao_index / 100, color='r', label='DCPP')

# Plot the ASF20C - don't need to shift the years as takes a forward running mean
ax.plot(asf20c_years,
        asf20c_nao_index / 100, color='b', label='ASF20C')

# Set the x and y limits
ax.set_ylim([-10, 10])

# Set a horizontal line at zero
ax.axhline(y=0, color='k', linestyle='--')

# Set the legend in the lower left
ax.legend(loc='lower left')
# Out:
# (84,)
# (84,)
# (54,)
# (54,)
