# %%
# Plotting notebook for the project
# Imports
import argparse
import os
import sys
import glob
import re

# Third-party imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xarray as xr
import cartopy.crs as ccrs
from datetime import datetime
import scipy.stats as stats

# import cdo
from cdo import *
cdo = Cdo()

# Local imports
sys.path.append('/home/users/benhutch/skill-maps')
import dictionaries as dic
import functions as fnc

# %%
# for the GIF plots
# !pip install Pillow
# from PIL import Image

# %%
# Set up the arguments to be used
# Defined globally in this notebook
variable = "psl"
region = "north-atlantic"
season = "DJFM"
forecast_range = "2-9"

# %%
# Load the model data
datasets = fnc.load_data(dic.base_dir, dic.models, variable, region, forecast_range, season)
# Out:
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/north-atlantic/years_2-9/DJFM/outputs/mergetime/*.nc
# Files for BCC-CSM2-MR: ['/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_north-atlantic_2-9_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_north-atlantic_2-9_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_north-atlantic_2-9_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_north-atlantic_2-9_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_north-atlantic_2-9_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_north-atlantic_2-9_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_north-atlantic_2-9_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_north-atlantic_2-9_DJFM-r1i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/north-atlantic/years_2-9/DJFM/outputs/mergetime/*.nc
# Files for MPI-ESM1-2-HR: ['/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_north-atlantic_2-9_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_north-atlantic_2-9_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_north-atlantic_2-9_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_north-atlantic_2-9_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_north-atlantic_2-9_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_north-atlantic_2-9_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_north-atlantic_2-9_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_north-atlantic_2-9_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_north-atlantic_2-9_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_north-atlantic_2-9_DJFM-r10i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/CanESM5/north-atlantic/years_2-9/DJFM/outputs/mergetime/*.nc
# Files for CanESM5: ['/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_north-atlantic_2-9_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_north-atlantic_2-9_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_north-atlantic_2-9_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_north-atlantic_2-9_DJFM-r10i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_north-atlantic_2-9_DJFM-r15i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_north-atlantic_2-9_DJFM-r11i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_north-atlantic_2-9_DJFM-r13i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_north-atlantic_2-9_DJFM-r14i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_north-atlantic_2-9_DJFM-r12i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_north-atlantic_2-9_DJFM-r16i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_north-atlantic_2-9_DJFM-r18i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_north-atlantic_2-9_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_north-atlantic_2-9_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_north-atlantic_2-9_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_north-atlantic_2-9_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_north-atlantic_2-9_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_north-atlantic_2-9_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_north-atlantic_2-9_DJFM-r19i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_north-atlantic_2-9_DJFM-r20i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_north-atlantic_2-9_DJFM-r17i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/*.nc
# Files for CMCC-CM2-SR5: ['/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r10i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r3i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/north-atlantic/years_2-9/DJFM/outputs/mergetime/*.nc
# Files for HadGEM3-GC31-MM: ['/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_north-atlantic_2-9_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_north-atlantic_2-9_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_north-atlantic_2-9_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_north-atlantic_2-9_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_north-atlantic_2-9_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_north-atlantic_2-9_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_north-atlantic_2-9_DJFM-r10i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_north-atlantic_2-9_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_north-atlantic_2-9_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_north-atlantic_2-9_DJFM-r9i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/north-atlantic/years_2-9/DJFM/outputs/mergetime/*.nc
# Files for EC-Earth3: ['/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_north-atlantic_2-9_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_north-atlantic_2-9_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_north-atlantic_2-9_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_north-atlantic_2-9_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_north-atlantic_2-9_DJFM-r9i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_north-atlantic_2-9_DJFM-r10i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_north-atlantic_2-9_DJFM-r10i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_north-atlantic_2-9_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_north-atlantic_2-9_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_north-atlantic_2-9_DJFM-r6i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_north-atlantic_2-9_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_north-atlantic_2-9_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_north-atlantic_2-9_DJFM-r7i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_north-atlantic_2-9_DJFM-r8i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_north-atlantic_2-9_DJFM-r8i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/north-atlantic/years_2-9/DJFM/outputs/mergetime/*.nc
# Files for MPI-ESM1-2-LR: ['/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_north-atlantic_2-9_DJFM-r13i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_north-atlantic_2-9_DJFM-r16i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_north-atlantic_2-9_DJFM-r15i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_north-atlantic_2-9_DJFM-r14i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_north-atlantic_2-9_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_north-atlantic_2-9_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_north-atlantic_2-9_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_north-atlantic_2-9_DJFM-r12i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_north-atlantic_2-9_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_north-atlantic_2-9_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_north-atlantic_2-9_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_north-atlantic_2-9_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_north-atlantic_2-9_DJFM-r11i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_north-atlantic_2-9_DJFM-r10i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_north-atlantic_2-9_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_north-atlantic_2-9_DJFM-r4i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/north-atlantic/years_2-9/DJFM/outputs/mergetime/*.nc
# Files for FGOALS-f3-L: ['/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_north-atlantic_2-9_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_north-atlantic_2-9_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_north-atlantic_2-9_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_north-atlantic_2-9_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_north-atlantic_2-9_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_north-atlantic_2-9_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_north-atlantic_2-9_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_north-atlantic_2-9_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_north-atlantic_2-9_DJFM-r7i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/MIROC6/north-atlantic/years_2-9/DJFM/outputs/mergetime/*.nc
# Files for MIROC6: ['/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MIROC6_psl_north-atlantic_2-9_DJFM-r10i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MIROC6_psl_north-atlantic_2-9_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MIROC6_psl_north-atlantic_2-9_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MIROC6_psl_north-atlantic_2-9_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MIROC6_psl_north-atlantic_2-9_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MIROC6_psl_north-atlantic_2-9_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MIROC6_psl_north-atlantic_2-9_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MIROC6_psl_north-atlantic_2-9_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MIROC6_psl_north-atlantic_2-9_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_MIROC6_psl_north-atlantic_2-9_DJFM-r4i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/north-atlantic/years_2-9/DJFM/outputs/mergetime/*.nc
# Files for IPSL-CM6A-LR: ['/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_north-atlantic_2-9_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_north-atlantic_2-9_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_north-atlantic_2-9_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_north-atlantic_2-9_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_north-atlantic_2-9_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_north-atlantic_2-9_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_north-atlantic_2-9_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_north-atlantic_2-9_DJFM-r10i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_north-atlantic_2-9_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_north-atlantic_2-9_DJFM-r8i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/north-atlantic/years_2-9/DJFM/outputs/mergetime/*.nc
# Files for CESM1-1-CAM5-CMIP5: ['/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_north-atlantic_2-9_DJFM-r21i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_north-atlantic_2-9_DJFM-r23i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_north-atlantic_2-9_DJFM-r33i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_north-atlantic_2-9_DJFM-r11i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_north-atlantic_2-9_DJFM-r35i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_north-atlantic_2-9_DJFM-r14i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_north-atlantic_2-9_DJFM-r16i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_north-atlantic_2-9_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_north-atlantic_2-9_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_north-atlantic_2-9_DJFM-r22i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_north-atlantic_2-9_DJFM-r12i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_north-atlantic_2-9_DJFM-r29i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_north-atlantic_2-9_DJFM-r19i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_north-atlantic_2-9_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_north-atlantic_2-9_DJFM-r31i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_north-atlantic_2-9_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_north-atlantic_2-9_DJFM-r15i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_north-atlantic_2-9_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_north-atlantic_2-9_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_north-atlantic_2-9_DJFM-r30i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_north-atlantic_2-9_DJFM-r18i1.nc', '/home/users/benhutch/skill-maps-processed-data/ ...
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/north-atlantic/years_2-9/DJFM/outputs/mergetime/*.nc
# Files for NorCPM1: ['/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_north-atlantic_2-9_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_north-atlantic_2-9_DJFM-r4i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_north-atlantic_2-9_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_north-atlantic_2-9_DJFM-r5i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_north-atlantic_2-9_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_north-atlantic_2-9_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_north-atlantic_2-9_DJFM-r8i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_north-atlantic_2-9_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_north-atlantic_2-9_DJFM-r7i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_north-atlantic_2-9_DJFM-r9i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_north-atlantic_2-9_DJFM-r10i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_north-atlantic_2-9_DJFM-r10i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_north-atlantic_2-9_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_north-atlantic_2-9_DJFM-r6i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_north-atlantic_2-9_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_north-atlantic_2-9_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_north-atlantic_2-9_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_north-atlantic_2-9_DJFM-r2i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_north-atlantic_2-9_DJFM-r3i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_north-atlantic_2-9_DJFM-r1i2.nc']

# %%
# Process the model data
variable_data, model_time = fnc.process_data(datasets, variable)
# Out:
# Dataset type: <class 'dict'>

# %%
# Choose the obs path based on the variable
if variable == "psl":
    obs_path = dic.obs_psl_na
elif variable == "tas":
    obs_path = dic.obs_tas
elif variable == "sfcWind":
    obs_path = dic.obs_sfcWind
elif variable == "rsds":
    obs_path = dic.obs_rsds
else:
    print("Error: variable not found")
    sys.exit()

# choose the obs var name based on the variable
if variable == "psl":
    obs_var_name = "psl"
elif variable == "tas":
    obs_var_name = "tas"
elif variable == "sfcWind":
    obs_var_name = "sfcWind"
elif variable == "rsds":
    obs_var_name = "rsds"
else:
    print("Error: variable not found")
    sys.exit()

# %%
# # Process the observations
obs = fnc.process_observations(variable, region, dic.north_atlantic_grid_obs, 
                               forecast_range, season, dic.obs, obs_var_name)
# Out:
# File already exists
# Regridded and selected region dataset: <xarray.DataArray 'time' (time: 259)>
# array(['1959-01-01T00:00:00.000000000', '1959-02-01T00:00:00.000000000',
#        '1959-03-01T00:00:00.000000000', ..., '2023-01-01T00:00:00.000000000',
#        '2023-02-01T00:00:00.000000000', '2023-03-01T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 1959-01-01 1959-02-01 ... 2023-03-01
# Attributes:
#     standard_name:  time
#     long_name:      time
#     axis:           T
# Forecast range: 2 - 9
# Rolling mean range: 8

# %%
obs.values
# Out:
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        ...,
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]])

# %%
# # # check the values of obs
# obs["var151"]

# # count how many value are NaN
# nan_count = np.isnan(obs["var151"]).sum()

# print(nan_count.values)

# # count how many values are not NaN
# not_nan_count = np.count_nonzero(obs["var151"])

# print(not_nan_count)

# # calculate the percentage of NaN values
# nan_percentage = nan_count / (nan_count + not_nan_count) * 100

# # # print the percentage of NaN values
# # print("Percentage of NaN values in obs: ", nan_percentage)

# %%
rfield, pfield, obs_lons_converted, lons_converted = fnc.calculate_spatial_correlations(obs, variable_data, dic.models, variable)
# Out:
# extracting data for model: BCC-CSM2-MR
# extracting data for model: MPI-ESM1-2-HR
# extracting data for model: CanESM5
# extracting data for model: CMCC-CM2-SR5
# extracting data for model: HadGEM3-GC31-MM
# extracting data for model: EC-Earth3
# extracting data for model: MPI-ESM1-2-LR
# extracting data for model: FGOALS-f3-L
# extracting data for model: MIROC6
# extracting data for model: IPSL-CM6A-LR
# extracting data for model: CESM1-1-CAM5-CMIP5
# extracting data for model: NorCPM1
# var name for obs msl
# Correlation coefficients range from -0.469 to 0.625
# P-values range from 0.000 to 0.999

# %%
# # print the rfield
# # print(rfield)
# # visualise the distribution of r values
# # as a histogram
# plt.hist(rfield, bins=20)

# %%
# # Call the function to plot the spatial correlations of these
fnc.plot_correlations(dic.models, rfield, pfield, obs, variable, region, season, forecast_range, dic.plots_dir, obs_lons_converted, lons_converted, dic.azores_grid, dic.iceland_grid, dic.uk_n_box, dic.uk_s_box)

# %%
# Test the new function which plots the spatial correlations as subplots
# For all of the models
fnc.plot_correlations_subplots(dic.models, obs, variable_data, variable, region, season, forecast_range, dic.plots_dir, dic.azores_grid, dic.iceland_grid, dic.uk_n_box, dic.uk_s_box)
# Out:
# Processing model: BCC-CSM2-MR
# extracting data for model: BCC-CSM2-MR
# var name for obs msl
# Correlation coefficients range from -0.194 to 0.613
# P-values range from 0.000 to 1.000
# Processing model: MPI-ESM1-2-HR
# extracting data for model: MPI-ESM1-2-HR
# var name for obs msl
# Correlation coefficients range from -0.400 to 0.592
# P-values range from 0.000 to 1.000
# Processing model: CanESM5
# extracting data for model: CanESM5
# var name for obs msl
# Correlation coefficients range from -0.567 to 0.587
# P-values range from 0.000 to 0.996
# Processing model: CMCC-CM2-SR5
# extracting data for model: CMCC-CM2-SR5
# var name for obs msl
# Correlation coefficients range from -0.369 to 0.515
# P-values range from 0.000 to 1.000
# Processing model: HadGEM3-GC31-MM
# extracting data for model: HadGEM3-GC31-MM
# var name for obs msl
# Correlation coefficients range from -0.541 to 0.464
# P-values range from 0.000 to 0.998
# Processing model: EC-Earth3
# extracting data for model: EC-Earth3
# var name for obs msl
# Correlation coefficients range from -0.563 to 0.386
# P-values range from 0.000 to 1.000
# Processing model: MPI-ESM1-2-LR
# extracting data for model: MPI-ESM1-2-LR
# var name for obs msl
# Correlation coefficients range from -0.353 to 0.724
# P-values range from 0.000 to 0.998
# Processing model: FGOALS-f3-L
# extracting data for model: FGOALS-f3-L
# var name for obs msl
# Correlation coefficients range from -0.297 to 0.438
# P-values range from 0.001 to 1.000
# Processing model: MIROC6
# extracting data for model: MIROC6
# var name for obs msl
# Correlation coefficients range from -0.562 to 0.619
# P-values range from 0.000 to 1.000
# Processing model: IPSL-CM6A-LR
# extracting data for model: IPSL-CM6A-LR
# var name for obs msl
# Correlation coefficients range from -0.498 to 0.525
# P-values range from 0.000 to 1.000
# Processing model: CESM1-1-CAM5-CMIP5
# extracting data for model: CESM1-1-CAM5-CMIP5
# var name for obs msl
# Correlation coefficients range from -0.529 to 0.677
# P-values range from 0.000 to 0.998
# Processing model: NorCPM1
# extracting data for model: NorCPM1
# var name for obs msl
# Correlation coefficients range from -0.422 to 0.384
# P-values range from 0.001 to 0.998

# %%
# Now globally
# Need to process the model data first
region = "global"

# %%
# Load the model data
# Now for the global region
datasets = fnc.load_data(dic.base_dir, dic.models, variable, region, forecast_range, season)
# Out:
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/global/years_2-9/DJFM/outputs/mergetime/*.nc
# Files for BCC-CSM2-MR: ['/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/global/years_2-9/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_global_2-9_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/global/years_2-9/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_global_2-9_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/global/years_2-9/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_global_2-9_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/global/years_2-9/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_global_2-9_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/global/years_2-9/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_global_2-9_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/global/years_2-9/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_global_2-9_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/global/years_2-9/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_global_2-9_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/global/years_2-9/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_global_2-9_DJFM-r1i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-9/DJFM/outputs/mergetime/*.nc
# Files for MPI-ESM1-2-HR: ['/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_global_2-9_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_global_2-9_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_global_2-9_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_global_2-9_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_global_2-9_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_global_2-9_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_global_2-9_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_global_2-9_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_global_2-9_DJFM-r10i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_global_2-9_DJFM-r9i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-9/DJFM/outputs/mergetime/*.nc
# Files for CanESM5: ['/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-9_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-9_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-9_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-9_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-9_DJFM-r19i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-9_DJFM-r15i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-9_DJFM-r14i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-9_DJFM-r16i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-9_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-9_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-9_DJFM-r20i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-9_DJFM-r17i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-9_DJFM-r18i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-9_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-9_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-9_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-9_DJFM-r10i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-9_DJFM-r11i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-9_DJFM-r12i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-9_DJFM-r13i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-9/DJFM/outputs/mergetime/*.nc
# Files for CMCC-CM2-SR5: ['/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_global_2-9_DJFM-r10i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_global_2-9_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_global_2-9_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_global_2-9_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_global_2-9_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_global_2-9_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_global_2-9_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_global_2-9_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_global_2-9_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_global_2-9_DJFM-r4i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-9/DJFM/outputs/mergetime/*.nc
# Files for HadGEM3-GC31-MM: ['/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-9/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_global_2-9_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-9/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_global_2-9_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-9/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_global_2-9_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-9/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_global_2-9_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-9/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_global_2-9_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-9/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_global_2-9_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-9/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_global_2-9_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-9/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_global_2-9_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-9/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_global_2-9_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-9/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_global_2-9_DJFM-r10i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-9/DJFM/outputs/mergetime/*.nc
# Files for EC-Earth3: ['/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-9/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-9_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-9/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-9_DJFM-r7i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-9/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-9_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-9/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-9_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-9/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-9_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-9/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-9_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-9/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-9_DJFM-r6i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-9/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-9_DJFM-r9i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-9/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-9_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-9/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-9_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-9/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-9_DJFM-r8i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-9/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-9_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-9/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-9_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-9/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-9_DJFM-r10i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-9/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-9_DJFM-r10i2.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-9/DJFM/outputs/mergetime/*.nc
# Files for MPI-ESM1-2-LR: ['/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-9_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-9_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-9_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-9_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-9_DJFM-r12i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-9_DJFM-r13i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-9_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-9_DJFM-r14i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-9_DJFM-r15i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-9_DJFM-r16i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-9_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-9_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-9_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-9_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-9_DJFM-r10i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-9/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-9_DJFM-r11i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/global/years_2-9/DJFM/outputs/mergetime/*.nc
# Files for FGOALS-f3-L: ['/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/global/years_2-9/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_global_2-9_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/global/years_2-9/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_global_2-9_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/global/years_2-9/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_global_2-9_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/global/years_2-9/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_global_2-9_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/global/years_2-9/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_global_2-9_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/global/years_2-9/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_global_2-9_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/global/years_2-9/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_global_2-9_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/global/years_2-9/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_global_2-9_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/global/years_2-9/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_global_2-9_DJFM-r7i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-9/DJFM/outputs/mergetime/*.nc
# Files for MIROC6: ['/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-9/DJFM/outputs/mergetime/mergetime_MIROC6_psl_global_2-9_DJFM-r10i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-9/DJFM/outputs/mergetime/mergetime_MIROC6_psl_global_2-9_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-9/DJFM/outputs/mergetime/mergetime_MIROC6_psl_global_2-9_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-9/DJFM/outputs/mergetime/mergetime_MIROC6_psl_global_2-9_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-9/DJFM/outputs/mergetime/mergetime_MIROC6_psl_global_2-9_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-9/DJFM/outputs/mergetime/mergetime_MIROC6_psl_global_2-9_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-9/DJFM/outputs/mergetime/mergetime_MIROC6_psl_global_2-9_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-9/DJFM/outputs/mergetime/mergetime_MIROC6_psl_global_2-9_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-9/DJFM/outputs/mergetime/mergetime_MIROC6_psl_global_2-9_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-9/DJFM/outputs/mergetime/mergetime_MIROC6_psl_global_2-9_DJFM-r4i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-9/DJFM/outputs/mergetime/*.nc
# Files for IPSL-CM6A-LR: ['/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-9/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_global_2-9_DJFM-r10i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-9/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_global_2-9_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-9/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_global_2-9_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-9/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_global_2-9_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-9/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_global_2-9_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-9/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_global_2-9_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-9/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_global_2-9_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-9/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_global_2-9_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-9/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_global_2-9_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-9/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_global_2-9_DJFM-r3i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-9/DJFM/outputs/mergetime/*.nc
# Files for CESM1-1-CAM5-CMIP5: ['/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-9_DJFM-r14i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-9_DJFM-r15i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-9_DJFM-r27i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-9_DJFM-r26i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-9_DJFM-r25i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-9_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-9_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-9_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-9_DJFM-r18i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-9_DJFM-r17i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-9_DJFM-r23i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-9_DJFM-r24i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-9_DJFM-r22i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-9_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-9_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-9_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-9_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-9_DJFM-r16i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-9_DJFM-r20i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-9_DJFM-r19i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-9_DJFM-r21i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-9_DJFM-r12i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-9/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-9_DJFM-r13i1.nc', '/home/users/benhutch/skill-maps-processed- ...
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-9/DJFM/outputs/mergetime/*.nc
# Files for NorCPM1: ['/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-9_DJFM-r2i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-9_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-9_DJFM-r5i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-9_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-9_DJFM-r4i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-9_DJFM-r3i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-9_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-9_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-9_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-9_DJFM-r1i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-9_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-9_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-9_DJFM-r10i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-9_DJFM-r10i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-9_DJFM-r9i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-9_DJFM-r6i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-9_DJFM-r7i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-9_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-9_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-9/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-9_DJFM-r8i2.nc']

# %%
# Process the model data
# Again, this is for the global region
variable_data, model_time = fnc.process_data(datasets, variable)
# Out:
# Dataset type: <class 'dict'>

# %%
# Choose the obs path based on the variable
if variable == "psl":
    obs_path = dic.obs_psl_na
elif variable == "tas":
    obs_path = dic.obs_tas
elif variable == "sfcWind":
    obs_path = dic.obs_sfcWind
elif variable == "rsds":
    obs_path = dic.obs_rsds
else:
    print("Error: variable not found")
    sys.exit()

# choose the obs var name based on the variable
if variable == "psl":
    obs_var_name = "psl"
elif variable == "tas":
    obs_var_name = "tas"
elif variable == "sfcWind":
    obs_var_name = "sfcWind"
elif variable == "rsds":
    obs_var_name = "rsds"
else:
    print("Error: variable not found")
    sys.exit()

# %%
# Process the observations
# For the global region
# # Process the observations
# This function doesn't select the region, so no need to worry about the dic. variable
obs = fnc.process_observations(variable, region, dic.north_atlantic_grid_obs, 
                               forecast_range, season, dic.obs, obs_var_name)
# Out:
# File already exists
# Regridded and selected region dataset: <xarray.DataArray 'time' (time: 259)>
# array(['1959-01-01T00:00:00.000000000', '1959-02-01T00:00:00.000000000',
#        '1959-03-01T00:00:00.000000000', ..., '2023-01-01T00:00:00.000000000',
#        '2023-02-01T00:00:00.000000000', '2023-03-01T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 1959-01-01 1959-02-01 ... 2023-03-01
# Attributes:
#     standard_name:  time
#     long_name:      time
#     axis:           T
# Forecast range: 2 - 9
# Rolling mean range: 8

# %%
obs
# Out:
# <xarray.DataArray 'msl' (time: 65, lat: 72, lon: 144)>
# dask.array<truediv, shape=(65, 72, 144), dtype=float64, chunksize=(8, 72, 144), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 1959-12-31 1960-12-31 ... 2023-12-31
#   * lon      (lon) float64 -180.0 -177.5 -175.0 -172.5 ... 172.5 175.0 177.5
#   * lat      (lat) float64 -90.0 -87.5 -85.0 -82.5 -80.0 ... 80.0 82.5 85.0 87.5

# %%
# Calculate the r and p fields for the global region
rfield, pfield, obs_lons_converted, lons_converted = fnc.calculate_spatial_correlations(obs, variable_data, dic.models, variable)
# Out:
# extracting data for model: BCC-CSM2-MR
# extracting data for model: MPI-ESM1-2-HR
# extracting data for model: CanESM5
# extracting data for model: CMCC-CM2-SR5
# extracting data for model: HadGEM3-GC31-MM
# extracting data for model: EC-Earth3
# extracting data for model: MPI-ESM1-2-LR
# extracting data for model: FGOALS-f3-L
# extracting data for model: MIROC6
# extracting data for model: IPSL-CM6A-LR
# extracting data for model: CESM1-1-CAM5-CMIP5
# extracting data for model: NorCPM1
# var name for obs msl
# Correlation coefficients range from -0.697 to 0.968
# P-values range from 0.000 to 0.999

# %%
# # Plot the model and obs data to have a look at the data
# fnc.plot_model_data(variable_data, obs, dic.test_model_bcc, dic.gif_plots_dir)

# %%
# Plot the global multi-model spatial correlations
# # Call the function to plot the spatial correlations of these
fnc.plot_correlations(dic.models, rfield, pfield, obs, variable, region, season, forecast_range, dic.plots_dir, obs_lons_converted, lons_converted, dic.azores_grid, dic.iceland_grid, dic.uk_n_box, dic.uk_s_box)

# %%
# Now for the global individual model subplots
# Test the new function which plots the spatial correlations as subplots
# For all of the models
fnc.plot_correlations_subplots(dic.models, obs, variable_data, variable, region, season, forecast_range, dic.plots_dir, dic.azores_grid, dic.iceland_grid, dic.uk_n_box, dic.uk_s_box)
# Out:
# Processing model: BCC-CSM2-MR
# extracting data for model: BCC-CSM2-MR
# var name for obs msl
# Correlation coefficients range from -0.660 to 0.889
# P-values range from 0.000 to 1.000
# Processing model: MPI-ESM1-2-HR
# extracting data for model: MPI-ESM1-2-HR
# var name for obs msl
# Correlation coefficients range from -0.771 to 0.947
# P-values range from 0.000 to 1.000
# Processing model: CanESM5
# extracting data for model: CanESM5
# var name for obs msl
# Correlation coefficients range from -0.798 to 0.952
# P-values range from 0.000 to 0.999
# Processing model: CMCC-CM2-SR5
# extracting data for model: CMCC-CM2-SR5
# var name for obs msl
# Correlation coefficients range from -0.575 to 0.902
# P-values range from 0.000 to 1.000
# Processing model: HadGEM3-GC31-MM
# extracting data for model: HadGEM3-GC31-MM
# var name for obs msl
# Correlation coefficients range from -0.671 to 0.945
# P-values range from 0.000 to 0.999
# Processing model: EC-Earth3
# extracting data for model: EC-Earth3
# var name for obs msl
# Correlation coefficients range from -0.615 to 0.922
# P-values range from 0.000 to 1.000
# Processing model: MPI-ESM1-2-LR
# extracting data for model: MPI-ESM1-2-LR
# var name for obs msl
# Correlation coefficients range from -0.788 to 0.948
# P-values range from 0.000 to 0.999
# Processing model: FGOALS-f3-L
# extracting data for model: FGOALS-f3-L
# var name for obs msl
# Correlation coefficients range from -0.472 to 0.923
# P-values range from 0.000 to 1.000
# Processing model: MIROC6
# extracting data for model: MIROC6
# var name for obs msl
# Correlation coefficients range from -0.707 to 0.945
# P-values range from 0.000 to 1.000
# Processing model: IPSL-CM6A-LR
# extracting data for model: IPSL-CM6A-LR
# var name for obs msl
# Correlation coefficients range from -0.534 to 0.927
# P-values range from 0.000 to 1.000
# Processing model: CESM1-1-CAM5-CMIP5
# extracting data for model: CESM1-1-CAM5-CMIP5
# var name for obs msl
# Correlation coefficients range from -0.722 to 0.952
# P-values range from 0.000 to 1.000
# Processing model: NorCPM1
# extracting data for model: NorCPM1
# var name for obs msl
# Correlation coefficients range from -0.776 to 0.949
# P-values range from 0.000 to 1.000

# %%
# Now for the year range 2-5
# Plot the skill for the global region first
# Make sure that the variables are set up correctly
variable = "psl"
region = "global"
season = "DJFM"
forecast_range = "2-5"

# %%
# Load the data
# For the global region, years 2-5, DJFM
datasets = fnc.load_data(dic.base_dir, dic.models, variable, region, forecast_range, season)
# Out:
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/global/years_2-5/DJFM/outputs/mergetime/*.nc
# Files for BCC-CSM2-MR: ['/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/global/years_2-5/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_global_2-5_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/global/years_2-5/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_global_2-5_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/global/years_2-5/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_global_2-5_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/global/years_2-5/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_global_2-5_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/global/years_2-5/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_global_2-5_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/global/years_2-5/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_global_2-5_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/global/years_2-5/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_global_2-5_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/global/years_2-5/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_global_2-5_DJFM-r2i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-5/DJFM/outputs/mergetime/*.nc
# Files for MPI-ESM1-2-HR: ['/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-5/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_global_2-5_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-5/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_global_2-5_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-5/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_global_2-5_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-5/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_global_2-5_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-5/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_global_2-5_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-5/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_global_2-5_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-5/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_global_2-5_DJFM-r10i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-5/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_global_2-5_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-5/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_global_2-5_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-5/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_global_2-5_DJFM-r1i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-5/DJFM/outputs/mergetime/*.nc
# Files for CanESM5: ['/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-5_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-5_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-5_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-5_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-5_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-5_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-5_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-5_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-5_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-5_DJFM-r19i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-5_DJFM-r18i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-5_DJFM-r17i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-5_DJFM-r16i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-5_DJFM-r14i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-5_DJFM-r20i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-5_DJFM-r15i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-5_DJFM-r12i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-5_DJFM-r10i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-5_DJFM-r13i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-5_DJFM-r11i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-5/DJFM/outputs/mergetime/*.nc
# Files for CMCC-CM2-SR5: ['/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_global_2-5_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_global_2-5_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_global_2-5_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_global_2-5_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_global_2-5_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_global_2-5_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_global_2-5_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_global_2-5_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_global_2-5_DJFM-r10i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_global_2-5_DJFM-r9i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-5/DJFM/outputs/mergetime/*.nc
# Files for HadGEM3-GC31-MM: ['/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-5/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_global_2-5_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-5/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_global_2-5_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-5/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_global_2-5_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-5/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_global_2-5_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-5/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_global_2-5_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-5/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_global_2-5_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-5/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_global_2-5_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-5/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_global_2-5_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-5/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_global_2-5_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-5/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_global_2-5_DJFM-r10i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-5/DJFM/outputs/mergetime/*.nc
# Files for EC-Earth3: ['/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-5/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-5_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-5/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-5_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-5/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-5_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-5/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-5_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-5/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-5_DJFM-r8i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-5/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-5_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-5/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-5_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-5/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-5_DJFM-r7i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-5/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-5_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-5/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-5_DJFM-r10i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-5/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-5_DJFM-r10i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-5/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-5_DJFM-r9i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-5/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-5_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-5/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-5_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-5/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-5_DJFM-r6i2.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-5/DJFM/outputs/mergetime/*.nc
# Files for MPI-ESM1-2-LR: ['/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-5/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-5_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-5/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-5_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-5/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-5_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-5/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-5_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-5/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-5_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-5/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-5_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-5/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-5_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-5/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-5_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-5/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-5_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-5/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-5_DJFM-r11i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-5/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-5_DJFM-r10i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-5/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-5_DJFM-r12i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-5/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-5_DJFM-r13i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-5/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-5_DJFM-r14i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-5/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-5_DJFM-r16i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-5/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-5_DJFM-r15i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/global/years_2-5/DJFM/outputs/mergetime/*.nc
# Files for FGOALS-f3-L: ['/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/global/years_2-5/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_global_2-5_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/global/years_2-5/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_global_2-5_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/global/years_2-5/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_global_2-5_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/global/years_2-5/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_global_2-5_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/global/years_2-5/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_global_2-5_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/global/years_2-5/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_global_2-5_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/global/years_2-5/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_global_2-5_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/global/years_2-5/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_global_2-5_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/global/years_2-5/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_global_2-5_DJFM-r9i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-5/DJFM/outputs/mergetime/*.nc
# Files for MIROC6: ['/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-5/DJFM/outputs/mergetime/mergetime_MIROC6_psl_global_2-5_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-5/DJFM/outputs/mergetime/mergetime_MIROC6_psl_global_2-5_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-5/DJFM/outputs/mergetime/mergetime_MIROC6_psl_global_2-5_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-5/DJFM/outputs/mergetime/mergetime_MIROC6_psl_global_2-5_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-5/DJFM/outputs/mergetime/mergetime_MIROC6_psl_global_2-5_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-5/DJFM/outputs/mergetime/mergetime_MIROC6_psl_global_2-5_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-5/DJFM/outputs/mergetime/mergetime_MIROC6_psl_global_2-5_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-5/DJFM/outputs/mergetime/mergetime_MIROC6_psl_global_2-5_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-5/DJFM/outputs/mergetime/mergetime_MIROC6_psl_global_2-5_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-5/DJFM/outputs/mergetime/mergetime_MIROC6_psl_global_2-5_DJFM-r10i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-5/DJFM/outputs/mergetime/*.nc
# Files for IPSL-CM6A-LR: ['/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-5/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_global_2-5_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-5/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_global_2-5_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-5/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_global_2-5_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-5/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_global_2-5_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-5/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_global_2-5_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-5/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_global_2-5_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-5/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_global_2-5_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-5/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_global_2-5_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-5/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_global_2-5_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-5/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_global_2-5_DJFM-r10i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-5/DJFM/outputs/mergetime/*.nc
# Files for CESM1-1-CAM5-CMIP5: ['/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-5_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-5_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-5_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-5_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-5_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-5_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-5_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-5_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-5_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-5_DJFM-r10i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-5_DJFM-r11i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-5_DJFM-r12i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-5_DJFM-r13i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-5_DJFM-r15i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-5_DJFM-r14i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-5_DJFM-r16i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-5_DJFM-r18i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-5_DJFM-r19i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-5_DJFM-r17i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-5_DJFM-r20i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-5_DJFM-r32i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-5_DJFM-r30i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-5/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-5_DJFM-r31i1.nc', '/home/users/benhutch/skill-maps-processed-da ...
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-5/DJFM/outputs/mergetime/*.nc
# Files for NorCPM1: ['/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-5/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-5_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-5/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-5_DJFM-r2i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-5/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-5_DJFM-r1i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-5/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-5_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-5/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-5_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-5/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-5_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-5/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-5_DJFM-r3i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-5/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-5_DJFM-r4i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-5/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-5_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-5/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-5_DJFM-r5i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-5/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-5_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-5/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-5_DJFM-r6i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-5/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-5_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-5/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-5_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-5/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-5_DJFM-r7i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-5/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-5_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-5/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-5_DJFM-r8i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-5/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-5_DJFM-r9i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-5/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-5_DJFM-r10i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-5/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-5_DJFM-r10i2.nc']

# %%
# Process the model data
variable_data, model_time = fnc.process_data(datasets, variable)
# Out:
# Dataset type: <class 'dict'>

# %%
# Choose the obs path based on the variable
if variable == "psl":
    obs_path = dic.obs_psl_na
elif variable == "tas":
    obs_path = dic.obs_tas
elif variable == "sfcWind":
    obs_path = dic.obs_sfcWind
elif variable == "rsds":
    obs_path = dic.obs_rsds
else:
    print("Error: variable not found")
    sys.exit()

# choose the obs var name based on the variable
if variable == "psl":
    obs_var_name = "psl"
elif variable == "tas":
    obs_var_name = "tas"
elif variable == "sfcWind":
    obs_var_name = "sfcWind"
elif variable == "rsds":
    obs_var_name = "rsds"
else:
    print("Error: variable not found")
    sys.exit()

# %%
# Process the observations for the global region and year 2-5 mean
# Check that the output is doing what we expect
obs = fnc.process_observations(variable, region, dic.north_atlantic_grid_obs,
                               forecast_range, season, dic.obs, obs_var_name)
# Out:
# File already exists
# Regridded and selected region dataset: <xarray.DataArray 'time' (time: 259)>
# array(['1959-01-01T00:00:00.000000000', '1959-02-01T00:00:00.000000000',
#        '1959-03-01T00:00:00.000000000', ..., '2023-01-01T00:00:00.000000000',
#        '2023-02-01T00:00:00.000000000', '2023-03-01T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 1959-01-01 1959-02-01 ... 2023-03-01
# Attributes:
#     standard_name:  time
#     long_name:      time
#     axis:           T
# Forecast range: 2 - 5
# Rolling mean range: 4

# %%
# Check that the obs looks like we expect it to
obs
# Out:
# <xarray.DataArray 'msl' (time: 65, lat: 72, lon: 144)>
# dask.array<truediv, shape=(65, 72, 144), dtype=float64, chunksize=(4, 72, 144), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 1959-12-31 1960-12-31 ... 2023-12-31
#   * lon      (lon) float64 -180.0 -177.5 -175.0 -172.5 ... 172.5 175.0 177.5
#   * lat      (lat) float64 -90.0 -87.5 -85.0 -82.5 -80.0 ... 80.0 82.5 85.0 87.5

# %%
# Calculate the r and p fields for the global region, year 2-9 mean
rfield, pfield, obs_lons_converted, lons_converted = fnc.calculate_spatial_correlations(
    obs, variable_data, dic.models, variable
)
# Out:
# extracting data for model: BCC-CSM2-MR
# extracting data for model: MPI-ESM1-2-HR
# extracting data for model: CanESM5
# extracting data for model: CMCC-CM2-SR5
# extracting data for model: HadGEM3-GC31-MM
# extracting data for model: EC-Earth3
# extracting data for model: MPI-ESM1-2-LR
# extracting data for model: FGOALS-f3-L
# extracting data for model: MIROC6
# extracting data for model: IPSL-CM6A-LR
# extracting data for model: CESM1-1-CAM5-CMIP5
# extracting data for model: NorCPM1
# var name for obs msl
# Correlation coefficients range from -0.511 to 0.887
# P-values range from 0.000 to 1.000

# %%
# Plot the correlations for the global region, year 2-9 mean
# Multi-model mean
fnc.plot_correlations(dic.models, rfield, pfield, obs, variable, region, season,
                      forecast_range, dic.plots_dir, obs_lons_converted, lons_converted,
                      dic.azores_grid, dic.iceland_grid, dic.uk_n_box, dic.uk_s_box)

# %%
# Now for the individual models
fnc.plot_correlations_subplots(dic.models, obs, variable_data, variable, region, season,
                                forecast_range, dic.plots_dir, dic.azores_grid, dic.iceland_grid,
                                  dic.uk_n_box, dic.uk_s_box)
# Out:
# Processing model: BCC-CSM2-MR
# extracting data for model: BCC-CSM2-MR
# var name for obs msl
# Correlation coefficients range from -0.459 to 0.868
# P-values range from 0.000 to 1.000
# Processing model: MPI-ESM1-2-HR
# extracting data for model: MPI-ESM1-2-HR
# var name for obs msl
# Correlation coefficients range from -0.565 to 0.837
# P-values range from 0.000 to 0.999
# Processing model: CanESM5
# extracting data for model: CanESM5
# var name for obs msl
# Correlation coefficients range from -0.684 to 0.866
# P-values range from 0.000 to 1.000
# Processing model: CMCC-CM2-SR5
# extracting data for model: CMCC-CM2-SR5
# var name for obs msl
# Correlation coefficients range from -0.459 to 0.831
# P-values range from 0.000 to 1.000
# Processing model: HadGEM3-GC31-MM
# extracting data for model: HadGEM3-GC31-MM
# var name for obs msl
# Correlation coefficients range from -0.556 to 0.814
# P-values range from 0.000 to 1.000
# Processing model: EC-Earth3
# extracting data for model: EC-Earth3
# var name for obs msl
# Correlation coefficients range from -0.519 to 0.846
# P-values range from 0.000 to 1.000
# Processing model: MPI-ESM1-2-LR
# extracting data for model: MPI-ESM1-2-LR
# var name for obs msl
# Correlation coefficients range from -0.623 to 0.872
# P-values range from 0.000 to 1.000
# Processing model: FGOALS-f3-L
# extracting data for model: FGOALS-f3-L
# var name for obs msl
# Correlation coefficients range from -0.406 to 0.811
# P-values range from 0.000 to 1.000
# Processing model: MIROC6
# extracting data for model: MIROC6
# var name for obs msl
# Correlation coefficients range from -0.450 to 0.828
# P-values range from 0.000 to 0.999
# Processing model: IPSL-CM6A-LR
# extracting data for model: IPSL-CM6A-LR
# var name for obs msl
# Correlation coefficients range from -0.444 to 0.823
# P-values range from 0.000 to 1.000
# Processing model: CESM1-1-CAM5-CMIP5
# extracting data for model: CESM1-1-CAM5-CMIP5
# var name for obs msl
# Correlation coefficients range from -0.644 to 0.892
# P-values range from 0.000 to 1.000
# Processing model: NorCPM1
# extracting data for model: NorCPM1
# var name for obs msl
# Correlation coefficients range from -0.684 to 0.830
# P-values range from 0.000 to 1.000

# %%
# Set up the variables for the obs processing function
# For the new run of the model years 2-3
variable = "psl"
region = "global"
region_grid = dic.gridspec_global
forecast_range = "2-3"
season = "DJFM"
observations_path = dic.obs
obs_var_name = "psl"

# %%
# Call the processing obs function
obs = fnc.process_observations(variable, region, region_grid, forecast_range, season, observations_path, obs_var_name)
# Out:
# File already exists
# Regridded and selected region dataset: <xarray.DataArray 'time' (time: 259)>
# array(['1959-01-01T00:00:00.000000000', '1959-02-01T00:00:00.000000000',
#        '1959-03-01T00:00:00.000000000', ..., '2023-01-01T00:00:00.000000000',
#        '2023-02-01T00:00:00.000000000', '2023-03-01T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 1959-01-01 1959-02-01 ... 2023-03-01
# Attributes:
#     standard_name:  time
#     long_name:      time
#     axis:           T
# Forecast range: 2 - 3
# Rolling mean range: 2

# %%
# Have a look at the obs
obs
# Out:
# <xarray.DataArray 'msl' (time: 65, lat: 72, lon: 144)>
# dask.array<truediv, shape=(65, 72, 144), dtype=float64, chunksize=(2, 72, 144), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 1959-12-31 1960-12-31 ... 2023-12-31
#   * lon      (lon) float64 -180.0 -177.5 -175.0 -172.5 ... 172.5 175.0 177.5
#   * lat      (lat) float64 -90.0 -87.5 -85.0 -82.5 -80.0 ... 80.0 82.5 85.0 87.5

# %%
# Load the data
datasets = fnc.load_data(dic.base_dir, dic.models, variable, region, forecast_range, season)
# Out:
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/global/years_2-3/DJFM/outputs/mergetime/*.nc
# Files for BCC-CSM2-MR: ['/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/global/years_2-3/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_global_2-3_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/global/years_2-3/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_global_2-3_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/global/years_2-3/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_global_2-3_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/global/years_2-3/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_global_2-3_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/global/years_2-3/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_global_2-3_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/global/years_2-3/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_global_2-3_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/global/years_2-3/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_global_2-3_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/BCC-CSM2-MR/global/years_2-3/DJFM/outputs/mergetime/mergetime_BCC-CSM2-MR_psl_global_2-3_DJFM-r8i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-3/DJFM/outputs/mergetime/*.nc
# Files for MPI-ESM1-2-HR: ['/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-3/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_global_2-3_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-3/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_global_2-3_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-3/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_global_2-3_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-3/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_global_2-3_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-3/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_global_2-3_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-3/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_global_2-3_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-3/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_global_2-3_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-3/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_global_2-3_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-3/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_global_2-3_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-HR/global/years_2-3/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-HR_psl_global_2-3_DJFM-r10i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-3/DJFM/outputs/mergetime/*.nc
# Files for CanESM5: ['/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-3_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-3_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-3_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-3_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-3_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-3_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-3_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-3_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-3_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-3_DJFM-r12i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-3_DJFM-r10i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-3_DJFM-r11i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-3_DJFM-r13i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-3_DJFM-r15i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-3_DJFM-r16i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-3_DJFM-r14i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-3_DJFM-r19i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-3_DJFM-r17i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-3_DJFM-r18i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CanESM5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CanESM5_psl_global_2-3_DJFM-r20i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-3/DJFM/outputs/mergetime/*.nc
# Files for CMCC-CM2-SR5: ['/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_global_2-3_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_global_2-3_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_global_2-3_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_global_2-3_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_global_2-3_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_global_2-3_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_global_2-3_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_global_2-3_DJFM-r10i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_global_2-3_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_global_2-3_DJFM-r9i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-3/DJFM/outputs/mergetime/*.nc
# Files for HadGEM3-GC31-MM: ['/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-3/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_global_2-3_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-3/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_global_2-3_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-3/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_global_2-3_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-3/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_global_2-3_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-3/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_global_2-3_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-3/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_global_2-3_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-3/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_global_2-3_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-3/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_global_2-3_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-3/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_global_2-3_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/HadGEM3-GC31-MM/global/years_2-3/DJFM/outputs/mergetime/mergetime_HadGEM3-GC31-MM_psl_global_2-3_DJFM-r10i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-3/DJFM/outputs/mergetime/*.nc
# Files for EC-Earth3: ['/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-3/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-3_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-3/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-3_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-3/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-3_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-3/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-3_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-3/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-3_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-3/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-3_DJFM-r7i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-3/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-3_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-3/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-3_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-3/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-3_DJFM-r8i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-3/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-3_DJFM-r9i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-3/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-3_DJFM-r10i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-3/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-3_DJFM-r10i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-3/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-3_DJFM-r6i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-3/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-3_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/EC-Earth3/global/years_2-3/DJFM/outputs/mergetime/mergetime_EC-Earth3_psl_global_2-3_DJFM-r5i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-3/DJFM/outputs/mergetime/*.nc
# Files for MPI-ESM1-2-LR: ['/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-3/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-3_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-3/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-3_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-3/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-3_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-3/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-3_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-3/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-3_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-3/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-3_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-3/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-3_DJFM-r11i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-3/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-3_DJFM-r10i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-3/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-3_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-3/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-3_DJFM-r14i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-3/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-3_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-3/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-3_DJFM-r13i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-3/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-3_DJFM-r12i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-3/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-3_DJFM-r16i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-3/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-3_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MPI-ESM1-2-LR/global/years_2-3/DJFM/outputs/mergetime/mergetime_MPI-ESM1-2-LR_psl_global_2-3_DJFM-r15i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/global/years_2-3/DJFM/outputs/mergetime/*.nc
# Files for FGOALS-f3-L: ['/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/global/years_2-3/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_global_2-3_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/global/years_2-3/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_global_2-3_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/global/years_2-3/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_global_2-3_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/global/years_2-3/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_global_2-3_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/global/years_2-3/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_global_2-3_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/global/years_2-3/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_global_2-3_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/global/years_2-3/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_global_2-3_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/global/years_2-3/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_global_2-3_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/FGOALS-f3-L/global/years_2-3/DJFM/outputs/mergetime/mergetime_FGOALS-f3-L_psl_global_2-3_DJFM-r8i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-3/DJFM/outputs/mergetime/*.nc
# Files for MIROC6: ['/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-3/DJFM/outputs/mergetime/mergetime_MIROC6_psl_global_2-3_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-3/DJFM/outputs/mergetime/mergetime_MIROC6_psl_global_2-3_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-3/DJFM/outputs/mergetime/mergetime_MIROC6_psl_global_2-3_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-3/DJFM/outputs/mergetime/mergetime_MIROC6_psl_global_2-3_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-3/DJFM/outputs/mergetime/mergetime_MIROC6_psl_global_2-3_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-3/DJFM/outputs/mergetime/mergetime_MIROC6_psl_global_2-3_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-3/DJFM/outputs/mergetime/mergetime_MIROC6_psl_global_2-3_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-3/DJFM/outputs/mergetime/mergetime_MIROC6_psl_global_2-3_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-3/DJFM/outputs/mergetime/mergetime_MIROC6_psl_global_2-3_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/MIROC6/global/years_2-3/DJFM/outputs/mergetime/mergetime_MIROC6_psl_global_2-3_DJFM-r10i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-3/DJFM/outputs/mergetime/*.nc
# Files for IPSL-CM6A-LR: ['/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-3/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_global_2-3_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-3/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_global_2-3_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-3/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_global_2-3_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-3/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_global_2-3_DJFM-r10i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-3/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_global_2-3_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-3/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_global_2-3_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-3/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_global_2-3_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-3/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_global_2-3_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-3/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_global_2-3_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/IPSL-CM6A-LR/global/years_2-3/DJFM/outputs/mergetime/mergetime_IPSL-CM6A-LR_psl_global_2-3_DJFM-r4i1.nc']
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-3/DJFM/outputs/mergetime/*.nc
# Files for CESM1-1-CAM5-CMIP5: ['/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-3_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-3_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-3_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-3_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-3_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-3_DJFM-r10i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-3_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-3_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-3_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-3_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-3_DJFM-r15i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-3_DJFM-r16i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-3_DJFM-r13i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-3_DJFM-r12i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-3_DJFM-r14i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-3_DJFM-r11i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-3_DJFM-r17i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-3_DJFM-r20i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-3_DJFM-r18i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-3_DJFM-r19i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-3_DJFM-r22i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-3_DJFM-r21i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CESM1-1-CAM5-CMIP5/global/years_2-3/DJFM/outputs/mergetime/mergetime_CESM1-1-CAM5-CMIP5_psl_global_2-3_DJFM-r23i1.nc', '/home/users/benhutch/skill-maps-processed-da ...
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-3/DJFM/outputs/mergetime/*.nc
# Files for NorCPM1: ['/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-3/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-3_DJFM-r1i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-3/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-3_DJFM-r5i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-3/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-3_DJFM-r5i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-3/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-3_DJFM-r4i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-3/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-3_DJFM-r6i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-3/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-3_DJFM-r1i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-3/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-3_DJFM-r2i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-3/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-3_DJFM-r3i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-3/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-3_DJFM-r4i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-3/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-3_DJFM-r3i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-3/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-3_DJFM-r2i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-3/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-3_DJFM-r7i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-3/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-3_DJFM-r8i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-3/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-3_DJFM-r7i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-3/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-3_DJFM-r6i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-3/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-3_DJFM-r8i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-3/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-3_DJFM-r9i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-3/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-3_DJFM-r10i1.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-3/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-3_DJFM-r9i2.nc', '/home/users/benhutch/skill-maps-processed-data/psl/NorCPM1/global/years_2-3/DJFM/outputs/mergetime/mergetime_NorCPM1_psl_global_2-3_DJFM-r10i2.nc']

# %%
# Process the model data
variable_data, model_time = fnc.process_data(datasets, variable)
# Out:
# Dataset type: <class 'dict'>

# %%
# Calculate the r and p fields for the global region, year 2-3 mean
rfield, pfield, obs_lons_converted, lons_converted = fnc.calculate_spatial_correlations(
    obs, variable_data, dic.models, variable
)
# Out:
# extracting data for model: BCC-CSM2-MR
# extracting data for model: MPI-ESM1-2-HR
# extracting data for model: CanESM5
# extracting data for model: CMCC-CM2-SR5
# extracting data for model: HadGEM3-GC31-MM
# extracting data for model: EC-Earth3
# extracting data for model: MPI-ESM1-2-LR
# extracting data for model: FGOALS-f3-L
# extracting data for model: MIROC6
# extracting data for model: IPSL-CM6A-LR
# extracting data for model: CESM1-1-CAM5-CMIP5
# extracting data for model: NorCPM1
# var name for obs msl
# Correlation coefficients range from -0.454 to 0.755
# P-values range from 0.000 to 1.000

# %%
# Plot the correlations for the global region, year 2-3 mean
fnc.plot_correlations(dic.models, rfield, pfield, obs, variable, region, season,
                      forecast_range, dic.plots_dir, obs_lons_converted, lons_converted,
                      dic.azores_grid, dic.iceland_grid, dic.uk_n_box, dic.uk_s_box)

# %%
# Now for the individual models for the global region, years 2-3 mean
fnc.plot_correlations_subplots(dic.models, obs, variable_data, variable, region, season,
                                forecast_range, dic.plots_dir, dic.azores_grid, dic.iceland_grid,
                                  dic.uk_n_box, dic.uk_s_box)
# Out:
# Processing model: BCC-CSM2-MR
# extracting data for model: BCC-CSM2-MR
# var name for obs msl
# Correlation coefficients range from -0.455 to 0.698
# P-values range from 0.000 to 1.000
# Processing model: MPI-ESM1-2-HR
# extracting data for model: MPI-ESM1-2-HR
# var name for obs msl
# Correlation coefficients range from -0.503 to 0.715
# P-values range from 0.000 to 1.000
# Processing model: CanESM5
# extracting data for model: CanESM5
# var name for obs msl
# Correlation coefficients range from -0.528 to 0.701
# P-values range from 0.000 to 1.000
# Processing model: CMCC-CM2-SR5
# extracting data for model: CMCC-CM2-SR5
# var name for obs msl
# Correlation coefficients range from -0.382 to 0.759
# P-values range from 0.000 to 0.999
# Processing model: HadGEM3-GC31-MM
# extracting data for model: HadGEM3-GC31-MM
# var name for obs msl
# Correlation coefficients range from -0.400 to 0.635
# P-values range from 0.000 to 1.000
# Processing model: EC-Earth3
# extracting data for model: EC-Earth3
# var name for obs msl
# Correlation coefficients range from -0.377 to 0.706
# P-values range from 0.000 to 1.000
# Processing model: MPI-ESM1-2-LR
# extracting data for model: MPI-ESM1-2-LR
# var name for obs msl
# Correlation coefficients range from -0.388 to 0.701
# P-values range from 0.000 to 1.000
# Processing model: FGOALS-f3-L
# extracting data for model: FGOALS-f3-L
# var name for obs msl
# Correlation coefficients range from -0.434 to 0.769
# P-values range from 0.000 to 1.000
# Processing model: MIROC6
# extracting data for model: MIROC6
# var name for obs msl
# Correlation coefficients range from -0.376 to 0.700
# P-values range from 0.000 to 1.000
# Processing model: IPSL-CM6A-LR
# extracting data for model: IPSL-CM6A-LR
# var name for obs msl
# Correlation coefficients range from -0.325 to 0.690
# P-values range from 0.000 to 1.000
# Processing model: CESM1-1-CAM5-CMIP5
# extracting data for model: CESM1-1-CAM5-CMIP5
# var name for obs msl
# Correlation coefficients range from -0.479 to 0.761
# P-values range from 0.000 to 1.000
# Processing model: NorCPM1
# extracting data for model: NorCPM1
# var name for obs msl
# Correlation coefficients range from -0.553 to 0.687
# P-values range from 0.000 to 0.999
