# %%
# Plotting notebook for the project
# Imports
import argparse
import os
import sys
import glob
import re

# Third-party imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xarray as xr
import cartopy.crs as ccrs
from datetime import datetime
import scipy.stats as stats

# Local imports
sys.path.append('/home/users/benhutch/skill-maps')
import dictionaries as dic
import functions as fnc

# %%
# Set up the arguments to be used
# Defined globally in this notebook
variable = "psl"
region = "north-atlantic"
season = "DJFM"
forecast_range = "2-9"

# %%
# Load the model data
datasets = fnc.load_data(dic.base_dir, dic.test_model, variable, region, forecast_range, season)
# Out:
# Searching for files in  /home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/*-anoms.nc
# Files for CMCC-CM2-SR5: ['/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r4i1-anoms.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r5i1-anoms.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r6i1-anoms.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r3i1-anoms.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r2i1-anoms.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r8i1-anoms.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r7i1-anoms.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r9i1-anoms.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r10i1-anoms.nc', '/home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r1i1-anoms.nc']
# /home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r4i1-anoms.nc
# Loading /home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r4i1-anoms.nc
# /home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r5i1-anoms.nc
# Loading /home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r5i1-anoms.nc
# /home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r6i1-anoms.nc
# Loading /home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r6i1-anoms.nc
# /home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r3i1-anoms.nc
# Loading /home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r3i1-anoms.nc
# /home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r2i1-anoms.nc
# Loading /home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r2i1-anoms.nc
# /home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r8i1-anoms.nc
# Loading /home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r8i1-anoms.nc
# /home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r7i1-anoms.nc
# Loading /home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r7i1-anoms.nc
# /home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r9i1-anoms.nc
# Loading /home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r9i1-anoms.nc
# /home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r10i1-anoms.nc
# Loading /home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r10i1-anoms.nc
# /home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r1i1-anoms.nc
# Loading /home/users/benhutch/skill-maps-processed-data/psl/CMCC-CM2-SR5/north-atlantic/years_2-9/DJFM/outputs/mergetime/mergetime_CMCC-CM2-SR5_psl_north-atlantic_2-9_DJFM-r1i1-anoms.nc

# %%
# Process the model data
variable_data, model_time = fnc.process_data(datasets, variable)
# Out:
# Dataset type: <class 'dict'>
# Variable data:  <xarray.DataArray 'psl' (time: 60, lat: 24, lon: 48)>
# dask.array<open_dataset-d1a297672907711a656eb128e6ee45f5psl, shape=(60, 24, 48), dtype=float32, chunksize=(50, 24, 48), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 1965-07-31 18:00:00 ... 2024-07-31 18:00:00
#   * lon      (lon) float64 -80.0 -77.5 -75.0 -72.5 -70.0 ... 30.0 32.5 35.0 37.5
#   * lat      (lat) float64 20.0 22.5 25.0 27.5 30.0 ... 67.5 70.0 72.5 75.0 77.5
# Attributes:
#     standard_name:  air_pressure_at_mean_sea_level
#     long_name:      Sea Level Pressure
#     units:          Pa
#     cell_methods:   area: time: mean
#     comment:        Sea Level Pressure
#     original_name:  PSL
#     cell_measures:  area: areacella
# Variable data type:  <class 'xarray.core.dataarray.DataArray'>
# Variable data dimensions:  3
# Variable data values:  [-0.19617188 -0.205625   -0.18679687  0.05835937 -0.29179686 -0.34851563
#  -0.0846875   0.06570312 -0.12445313 -0.14039062  0.12953125 -0.253125
#  -0.2128125   0.44117188 -0.25125    -0.2509375  -0.18804687  0.13867188
#  -0.00367187  0.03203125 -0.13171875  0.6003906   0.15578125  0.19882813
#   0.1875      0.20648438  0.29210937  0.1103125   0.33578125  0.04796875
#   0.34796876 -0.04109375  0.28453124  0.46804687  0.6388281   0.415625
#  -0.0365625   0.2521875  -0.3990625   0.29234374  0.01539063 -0.21703126
#   0.17523438 -0.25203124 -0.2115625   0.2940625  -0.51484376 -0.24476562
#  -0.15734375 -0.45867187 -0.3839844  -0.73578125 -0.3125     -0.30210936
#  -0.15640625  0.04953125  0.00921875 -0.3725     -0.21351562 -0.2667969 ]
# Variable data:  <xarray.DataArray 'psl' (time: 60, lat: 24, lon: 48)>
# dask.array<open_dataset-a67d29940445c894dba9d47ef9a5878cpsl, shape=(60, 24, 48), dtype=float32, chunksize=(50, 24, 48), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 1965-07-31 18:00:00 ... 2024-07-31 18:00:00
#   * lon      (lon) float64 -80.0 -77.5 -75.0 -72.5 -70.0 ... 30.0 32.5 35.0 37.5
#   * lat      (lat) float64 20.0 22.5 25.0 27.5 30.0 ... 67.5 70.0 72.5 75.0 77.5
# Attributes:
#     standard_name:  air_pressure_at_mean_sea_level
#     long_name:      Sea Level Pressure
#     units:          Pa
#     cell_methods:   area: time: mean
#     comment:        Sea Level Pressure
#     original_name:  PSL
#     cell_measures:  area: areacella
# Variable data type:  <class 'xarray.core.dataarray.DataArray'>
# Variable data dimensions:  3
# Variable data values:  [ 0.17125     0.0534375  -0.22539063  0.191875    0.03148438  0.06992187
#   0.03710938  0.18304688 -0.03       -0.06054688 -0.13070312 -0.0103125
#  -0.09601562  0.25828126  0.22304687 -0.28875    -0.3960156  -0.12125
#   0.13898438  0.35617188  0.12554687  0.22398438  0.3996094   0.49523437
#   0.21390624 -0.21570313  0.3060156   0.40335938 -0.18640625  0.33640626
#  -0.07835937 -0.03546875 -0.10804687  0.5259375   0.17523438  0.11429688
#   0.2490625   0.2303125   0.105       0.13210937  0.05476563  0.33492187
#  -0.18703125  0.141875    0.05796875 -0.01359375 -0.07132813 -0.045
#  -0.44929686 -0.38585937  0.0075     -0.1978125  -0.00835938 -0.37265626
#  -0.14898437  0.10140625 -0.38453126 -0.44       -0.07976563 -0.59625   ]
# Variable data:  <xarray.DataArray 'psl' (time: 60, lat: 24, lon: 48)>
# dask.array<open_dataset-f2068a43353c961dbc4f5733262ea3e6psl, shape=(60, 24, 48), dtype=float32, chunksize=(50, 24, 48), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 1965-07-31 18:00:00 ... 2024-07-31 18:00:00
#   * lon      (lon) float64 -80.0 -77.5 -75.0 -72.5 -70.0 ... 30.0 32.5 35.0 37.5
#   * lat      (lat) float64 20.0 22.5 25.0 27.5 30.0 ... 67.5 70.0 72.5 75.0 77.5
# Attributes:
#     standard_name:  air_pressure_at_mean_sea_level
#     long_name:      Sea Level Pressure
#     units:          Pa
#     cell_methods:   area: time: mean
#     comment:        Sea Level Pressure
#     original_name:  PSL
#     cell_measures:  area: areacella
# Variable data type:  <class 'xarray.core.dataarray.DataArray'>
# Variable data dimensions:  3
# Variable data values:  
#     cell_methods:   area: time: mean
#     comment:        Sea Level Pressure
#     original_name:  PSL
#     cell_measures:  area: areacella
# Variable data type:  <class 'xarray.core.dataarray.DataArray'>
# Variable data dimensions:  3
# Variable data values:  [ 0.00171875  0.12289062 -0.08671875 -0.0325     -0.3428125   0.15703125
#   0.35664064 -0.0953125  -0.10789063  0.12789063 -0.1596875  -0.21875
#  -0.10703125 -0.21328124  0.13125    -0.3015625  -0.33757812 -0.08039062
#  -0.02539062  0.53234375  0.7067969   0.2028125   0.5828906  -0.2675
#  -0.06007813  0.40679687  0.3985156   0.35710937  0.37414062  0.0975
#   0.20210938  0.07171875 -0.1596875   0.38        0.09296875 -0.08945312
#  -0.154375    0.131875    0.24851562  0.0503125  -0.20601563 -0.25445312
#   0.02289063  0.0459375  -0.03203125 -0.14828125 -0.235625   -0.37867188
#  -0.2025     -0.511875   -0.16421875 -0.18648438  0.16085938 -0.07148437
#  -0.49304688 -0.08484375 -0.130625   -0.15234375 -0.15351562 -0.04289062]

# %%
# Choose the obs path based on the variable
if variable == "psl":
    obs_path = dic.obs_psl
elif variable == "tas":
    obs_path = dic.obs_tas
elif variable == "sfcWind":
    obs_path = dic.obs_sfcWind
elif variable == "rsds":
    obs_path = dic.obs_rsds
else:
    print("Error: variable not found")
    sys.exit()

# choose the obs var name based on the variable
if variable == "psl":
    obs_var_name = dic.psl_label
elif variable == "tas":
    obs_var_name = dic.tas_label
elif variable == "sfcWind":
    obs_var_name = dic.sfc_wind_label
elif variable == "rsds":
    obs_var_name = dic.rsds_label
else:
    print("Error: variable not found")
    sys.exit()

# %%
# Process the observations
obs = fnc.process_observations(variable, region, dic.north_atlantic_grid, 
                               forecast_range, season, obs_path, obs_var_name)
# Out:
# Observations dataset: <xarray.Dataset>
# Dimensions:  (time: 252, lon: 1440, lat: 721)
# Coordinates:
#   * time     (time) datetime64[ns] 1960-01-01 1960-02-01 ... 2022-12-01
#   * lon      (lon) float64 0.0 0.25 0.5 0.75 1.0 ... 359.0 359.2 359.5 359.8
#   * lat      (lat) float64 90.0 89.75 89.5 89.25 ... -89.25 -89.5 -89.75 -90.0
# Data variables:
#     var151   (time, lat, lon) float32 dask.array<chunksize=(50, 721, 1440), meta=np.ndarray>
# Attributes:
#     CDI:          Climate Data Interface version 2.0.4 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     institution:  European Centre for Medium-Range Weather Forecasts
#     history:      Wed May 24 13:57:07 2023: cdo -f nc copy /home/users/benhut...
#     CDO:          Climate Data Operators version 2.0.4 (https://mpimet.mpg.de...
# Regridded observations dataset: <xarray.Dataset>
# Dimensions:  (time: 252, lat: 73, lon: 144)
# Coordinates:
#   * time     (time) datetime64[ns] 1960-01-01 1960-02-01 ... 2022-12-01
#   * lat      (lat) float64 -90.0 -87.5 -85.0 -82.5 -80.0 ... 82.5 85.0 87.5 90.0
#   * lon      (lon) float64 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
# Data variables:
#     var151   (time, lat, lon) float32 dask.array<chunksize=(50, 73, 144), meta=np.ndarray>
# Attributes:
#     CDI:          Climate Data Interface version 2.0.4 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     institution:  European Centre for Medium-Range Weather Forecasts
#     history:      Wed May 24 13:57:07 2023: cdo -f nc copy /home/users/benhut...
#     CDO:          Climate Data Operators version 2.0.4 (https://mpimet.mpg.de...
# Region grid dimensions: {'lon1': 280, 'lon2': 40, 'lat1': 60, 'lat2': 20}
# Processing dataset before season: <xarray.Dataset>
# Dimensions:  (lon: 49, time: 252, lat: 34)
# Coordinates:
#   * lon      (lon) float64 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * time     (time) datetime64[ns] 1960-01-01 1960-02-01 ... 2022-12-01
#   * lat      (lat) float64 20.0 22.5 25.0 27.5 30.0 ... 50.0 52.5 55.0 57.5 60.0
# Data variables:
#     var151   (time, lat, lon) float32 dask.array<chunksize=(50, 17, 49), meta=np.ndarray>
# Attributes:
#     CDI:          Climate Data Interface version 2.0.4 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     institution:  European Centre for Medium-Range Weather Forecasts
#     history:      Wed May 24 13:57:07 2023: cdo -f nc copy /home/users/benhut...
#     CDO:          Climate Data Operators version 2.0.4 (https://mpimet.mpg.de...
# Processing dataset: <xarray.Dataset>
# Dimensions:  (lon: 49, time: 252, lat: 34)
# Coordinates:
#   * lon      (lon) float64 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * time     (time) datetime64[ns] 1960-01-01 1960-02-01 ... 2022-12-01
#   * lat      (lat) float64 20.0 22.5 25.0 27.5 30.0 ... 50.0 52.5 55.0 57.5 60.0
# Data variables:
#     var151   (time, lat, lon) float32 dask.array<chunksize=(50, 17, 49), meta=np.ndarray>
# Attributes:
#     CDI:          Climate Data Interface version 2.0.4 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     institution:  European Centre for Medium-Range Weather Forecasts
#     history:      Wed May 24 13:57:07 2023: cdo -f nc copy /home/users/benhut...
#     CDO:          Climate Data Operators version 2.0.4 (https://mpimet.mpg.de...
# Season: DJFM
# Calculating annual mean anomalies for observations
# <xarray.Dataset>
# Dimensions:  (lon: 49, time: 252, lat: 34)
# Coordinates:
#   * lon      (lon) float64 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * time     (time) datetime64[ns] 1960-01-01 1960-02-01 ... 2022-12-01
#   * lat      (lat) float64 20.0 22.5 25.0 27.5 30.0 ... 50.0 52.5 55.0 57.5 60.0
# Data variables:
#     var151   (time, lat, lon) float32 dask.array<chunksize=(50, 17, 49), meta=np.ndarray>
# Forecast range: 2 - 9
# Rolling mean range: 8
# /opt/jaspy/lib/python3.10/site-packages/xarray/core/indexing.py:1228: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]

# %%
# Attempt to plot the data
fnc.plot_obs_data(obs)
# Out:
# Observations dimensions: Frozen({'time': 63, 'lon': 49, 'lat': 34})
# Observations variables: <xarray.Dataset>
# Dimensions:  (time: 63, lon: 49, lat: 34)
# Coordinates:
#   * time     (time) datetime64[ns] 1960-12-31 1961-12-31 ... 2022-12-31
#   * lon      (lon) float64 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * lat      (lat) float64 20.0 22.5 25.0 27.5 30.0 ... 50.0 52.5 55.0 57.5 60.0
# Data variables:
#     var151   (time, lat, lon) float64 dask.array<chunksize=(8, 17, 49), meta=np.ndarray>
# Observations dimensions: <xarray.Dataset>
# Dimensions:  (lon: 49, lat: 34)
# Coordinates:
#     time     datetime64[ns] 1960-12-31
#   * lon      (lon) float64 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * lat      (lat) float64 20.0 22.5 25.0 27.5 30.0 ... 50.0 52.5 55.0 57.5 60.0
# Data variables:
#     var151   (lat, lon) float64 dask.array<chunksize=(17, 49), meta=np.ndarray>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [7], in <cell line: 2>()
#       1 # Attempt to plot the data
# ----> 2 fnc.plot_obs_data(obs)
#
# File ~/skill-maps/python/functions.py:640, in plot_obs_data(obs_data)
#     637 fig, ax = plt.subplots(figsize=(6, 6), subplot_kw={'projection': ccrs.PlateCarree()})
#     639 # Plot the observations on the subplot
# --> 640 obs_var.plot(ax=ax, transform=ccrs.PlateCarree(), cmap='coolwarm', vmin=-2, vmax=2)
#     641 ax.set_title('Observations')
#     643 # Set the title of the figure
#     644 # fig.suptitle(f'{obs_data.variable.long_name} ({obs_data.variable.units})\n{obs_data.region} {obs_data.forecast_range} {obs_data.season}')
#     645
#     646 # Show the plot
#
# File /opt/jaspy/lib/python3.10/site-packages/xarray/plot/plot.py:866, in _PlotMethods.__call__(self, **kwargs)
#     865 def __call__(self, **kwargs):
# --> 866     return plot(self._da, **kwargs)
#
# File /opt/jaspy/lib/python3.10/site-packages/xarray/plot/plot.py:332, in plot(darray, row, col, col_wrap, ax, hue, rtol, subplot_kws, **kwargs)
#     328     plotfunc = hist
#     330 kwargs["ax"] = ax
# --> 332 return plotfunc(darray, **kwargs)
#
# File /opt/jaspy/lib/python3.10/site-packages/xarray/plot/plot.py:1210, in _plot2d.<locals>.newplotfunc(darray, x, y, figsize, size, aspect, ax, row, col, col_wrap, xincrease, yincrease, add_colorbar, add_labels, vmin, vmax, cmap, center, robust, extend, levels, infer_intervals, colors, subplot_kws, cbar_ax, cbar_kwargs, xscale, yscale, xticks, yticks, xlim, ylim, norm, **kwargs)
#    1206     raise ValueError("plt.imshow's `aspect` kwarg is not available in xarray")
#    1208 ax = get_axis(figsize, size, aspect, ax, **subplot_kws)
# -> 1210 primitive = plotfunc(
#    1211     xplt,
#    1212     yplt,
#    1213     zval,
#    1214     ax=ax,
#    1215     cmap=cmap_params["cmap"],
#    1216     vmin=cmap_params["vmin"],
#    1217     vmax=cmap_params["vmax"],
#    1218     norm=cmap_params["norm"],
#    1219     **kwargs,
#    1220 )
#    1222 # Label the plot with metadata
#    1223 if add_labels:
#
# File /opt/jaspy/lib/python3.10/site-packages/xarray/plot/plot.py:1470, in pcolormesh(x, y, z, ax, xscale, yscale, infer_intervals, **kwargs)
#    1464 if (
#    1465     infer_intervals
#    1466     and not np.issubdtype(y.dtype, str)
#    1467     and (np.shape(y)[0] == np.shape(z)[0])
#    1468 ):
#    1469     if len(y.shape) == 1:
# -> 1470         y = _infer_interval_breaks(y, check_monotonic=True, scale=yscale)
#    1471     else:
#    1472         # we have to infer the intervals on both axes
#    1473         y = _infer_interval_breaks(y, axis=1, scale=yscale)
#
# File /opt/jaspy/lib/python3.10/site-packages/xarray/plot/utils.py:798, in _infer_interval_breaks(coord, axis, scale, check_monotonic)
#     795 coord = np.asarray(coord)
#     797 if check_monotonic and not _is_monotonic(coord, axis=axis):
# --> 798     raise ValueError(
#     799         "The input coordinate is not sorted in increasing "
#     800         "order along axis %d. This can lead to unexpected "
#     801         "results. Consider calling the `sortby` method on "
#     802         "the input DataArray. To plot data with categorical "
#     803         "axes, consider using the `heatmap` function from "
#     804         "the `seaborn` statistical plotting library." % axis
#     805     )
#     807 # If logscale, compute the intervals in the logarithmic space
#     808 if scale == "log":
#
# ValueError: The input coordinate is not sorted in increasing order along axis 0. This can lead to unexpected results. Consider calling the `sortby` method on the input DataArray. To plot data with categorical axes, consider using the `heatmap` function from the `seaborn` statistical plotting library.
